# %% [markdown]
# # House price prediction for Denver Dataset
#
# In this case (Part II), there are two main tasks:
#
# - First, you will need to split the train data into train and validate data and tune the model hyperparameters to choose the best model. Submit the predicted prices for test data to Kaggle to compete for Prof. X's Prize!
#
# - Then you will examine the profit of the iBuyer business model based on the predicted price on the valid data.

# %% [markdown]
# You need to submit a report in pdf format containing the following material on canvas site:
#
# 1.   A plot of the training errors and validation errors over epochs for a base multilayer perceptron model with 2 hidden layers of sizes 256 and 128.
#
# 2.   A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64.
#
# 3.  A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization.
#
# 4. A plot of the training errors and validation errors over epochs for a  multilayer perceptron model with 4 hidden layers of sizes 512, 256, 128, 64
# and norm regularization and dropout layers.
#
# 5. A table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.
#
# 6. Your profit analysis of the the iBuyer business model based on the predicted price on the valid data and answers to the four questions therein.
#
#
# You also need to submit on canvas site:
#
# - The complete Juyputer notebook containing all your Pytorch code with explanations, along with a Markdown text explaining different parts if needed.
# -  A checkpoint.pth file containing all the necessary information to retrieve your best model and predictions.

# %% [markdown]
# ---
# ## Data Loading and Visualize Data

# %% [markdown]
# The train data and test data are available on Kaggle website.
# You can first download them, then upload them to the google colab, and then read the data using pandas.

# %%
import pandas as pd  # Importing pandas, which is a library for data manipulation and analysis
#TODO: Read the datasets
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %%
# Display the train dataframe
print(train_df.shape)
print(train_df.columns)
# Out:
# (11581, 17)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS', 'SALE_PRICE'],
#       dtype='object')

# %%
# Display the test dataframe
print(test_df.shape)
print(test_df.columns)
# Out:
# (4964, 16)
# Index(['ID', 'NBHD', 'PROP_CLASS', 'LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA',
#        'LAND_SQFT', 'GRD_AREA', 'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B',
#        'HLF_B', 'STORY', 'STYLE_CN', 'UNITS'],
#       dtype='object')

# %% [markdown]
# As you can see, we have 11581 training samples and 4964 test samples, each with 16 features. The training samples contain the sale_prices, which are the labels. The test samples do not contain the sale_prices, which we will predict by building a MLP model.

# %% [markdown]
# ### Visualization of SALE PRICES
#
# Let's take a closer look at the sale prices in the train data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt  # Importing matplotlib's pyplot, it provides a MATLAB-like interface for making plots and charts

# Set the style
sns.set(style="whitegrid")

# Create a histogram
plt.figure(figsize=(10, 6))
sns.histplot(train_df['SALE_PRICE'], bins=50, color='blue')
plt.title('Histogram of Sale Prices (Train Data)')
plt.xlabel('Sale Price')
plt.ylabel('Number of Properties')
plt.show()

# %% [markdown]
# Check the minimum and maximum sale_price in train data.

# %%
print(train_df['SALE_PRICE'].min())
print(train_df['SALE_PRICE'].max())
print(train_df['SALE_PRICE'].median())
# Out:
# 51000
# 1995000
# 431000.0

# %% [markdown]
# We see that the sale_price has a wide range from 50K to 2 million, with the median price 431K.

# %% [markdown]
# ### Visualization of Correlation
#
# We can also compute and visualize the correlation matrix.

# %%
# Compute the correlation matrix:
correlation_matrix = train_df.corr()

# 1. Increase the figure size for clarity
plt.figure(figsize=(8, 8))

# 2. Use a heatmap with annotations, a color map, and specific formatting for the annotations
ax = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={'size': 8})

# 3. Rotate the x-axis labels for better visibility
plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

# Rotate the y-axis labels
plt.setp(ax.get_yticklabels(), rotation=0)

# 4. Title and display
plt.title('Correlation Heatmap')
plt.tight_layout()  # This can help if any labels are still being cut off
plt.show()

# 5. Optionally save the figure with high resolution
# plt.savefig("heatmap.png", dpi=300)
# Out:
# <ipython-input-6-28da14c2e215>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = train_df.corr()

# %% [markdown]
# We can see that the Sale_Price has high correlation with Living_SQFT and number of Full Bathrooms.

# %% [markdown]
# ### Distribution of houses over different NBHD

# %%
# Compute the number of houses per neighborhood
House_by_NBHD = train_df['NBHD'].value_counts()
print(House_by_NBHD )
# Out:
# CENTRAL PARK                    1049
# GATEWAY / GREEN VALLEY RANCH     937
# UNION STATION                    369
# HAMPDEN                          346
# WINDSOR                          316
#                                 ...
# VALVERDE                          22
# GLOBEVILLE                        20
# SUN VALLEY                         8
# CORY - MERRILL                     4
# AURARIA                            1
# Name: NBHD, Length: 75, dtype: int64

# %%
# Filtering ZIP codes that appear more than once
filtered_House_by_NBHD = House_by_NBHD[House_by_NBHD > 200]
filtered_House_by_NBHD.plot(kind='bar', figsize=(10,6))
plt.title('Distribution of Houses by NBHD')
plt.ylabel('Number of Houses')
plt.xlabel('NBHD')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability, if necessary
plt.tight_layout()  # Ensure everything fits without overlapping
plt.show()

# %% [markdown]
# ---
# ## Data Preparation
#
# The first step when building a neural network model is getting your data into the proper form to feed into the network.
#
# - Train labels: We need to extract the sale prices from the train data as train labels. Since the house prices can take very large values, to make training fast it is helpful to define the train labels as the sale prices divided by a normalization factor.
#
# - **Handing non-numeric features**: Some of the house features are non-numeric. We will learn about how to process categorical data in the upcoming lectures. For now, you can  remove those non-numeric features and only train over the numeric features.
#
# - **Feature standardization**: When predicting house prices, you started from features that took a variety of ranges—some features had small floating-point values, and others had fairly large integer values. The model might be able to automatically adapt to such heterogeneous data, but it would definitely make learning more difficult. A widespread best practice for dealing with such data is to do feature-wise normalization: for each feature in the input data (a column in the input dataframe), we subtract the mean of the feature and divide by the standard deviation, so that the feature is centered around 0 and has
# a unit standard deviation. Note that here we combine the feature vectors in the train and test data. In this way, the train and test data go through the same normalization.
#
# - **Handling missing values**: There may exist some entries with missing values. After the feature standardization, we can impute the missing values with zeros.

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4964 entries, 0 to 4963
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4964 non-null   int64
#  1   NBHD         4964 non-null   object
#  2   PROP_CLASS   4964 non-null   object
#  3   LIVING_SQFT  4964 non-null   int64
#  4   FBSMT_SQFT   4964 non-null   int64
#  5   BSMT_AREA    4964 non-null   int64
#  6   LAND_SQFT    4964 non-null   int64
#  7   GRD_AREA     4964 non-null   int64
#  8   BLDG_AGE     4964 non-null   int64
#  9   RM_AGE       2623 non-null   float64
#  10  BED_RMS      4964 non-null   float64
#  11  FULL_B       4964 non-null   float64
#  12  HLF_B        4964 non-null   int64
#  13  STORY        4964 non-null   float64
#  14  STYLE_CN     4964 non-null   object
#  15  UNITS        4964 non-null   float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 620.6+ KB

# %% [markdown]
# We see that the sale_price in train data has a wide range from 50K to 2 million, with the median price 431K. We can divide the sale_price by 100K, so the normalized sale_price is between 0.5 and 20 in training data. Remember, when we output the predicted price for the test data, we need to multiply back the normalization factor.

# %%
#TODO: define labels for train data
normalization_factor=100000
train_labels = train_df['SALE_PRICE']/normalization_factor
train_df.drop('SALE_PRICE', axis=1, inplace=True) # drop the sale_prices in features.

# %% [markdown]
# The inplace parameter, when set to True , allows you to drop the rows or columns without returning a new DataFrame. The issue arises when the drop function reorders the DataFrame, which can be problematic when the order of your data matters

# %% [markdown]
# Note that both the training samples and test samples contain an ID column, which is not informative for predicting the house price. Thus we will drop the ID column.

# %%
train_ID=train_df['ID']
test_ID=test_df['ID']
train_df.drop('ID', axis=1, inplace=True)
test_df.drop('ID', axis=1, inplace=True)

# %%
# Then we combine the feature vectors in the train data and test data
features=pd.concat(objs=[train_df,test_df],axis=0)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16545 entries, 0 to 4963
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NBHD         16545 non-null  object
#  1   PROP_CLASS   16545 non-null  object
#  2   LIVING_SQFT  16545 non-null  int64
#  3   FBSMT_SQFT   16545 non-null  int64
#  4   BSMT_AREA    16545 non-null  int64
#  5   LAND_SQFT    16545 non-null  int64
#  6   GRD_AREA     16545 non-null  int64
#  7   BLDG_AGE     16545 non-null  int64
#  8   RM_AGE       8705 non-null   float64
#  9   BED_RMS      16545 non-null  float64
#  10  FULL_B       16545 non-null  float64
#  11  HLF_B        16545 non-null  int64
#  12  STORY        16545 non-null  float64
#  13  STYLE_CN     16545 non-null  object
#  14  UNITS        16545 non-null  float64
# dtypes: float64(5), int64(7), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# We see that there are three non-numeric features, namely `NBHD`, `PROP_CLASS`, and `STYLE_CN`. We will apply one-hot encoding to those non-numeric features in our model; you could also simply drop these non-numeric features.

# %%
numeric_features = features.dtypes[features.dtypes != 'object'].index
non_numeric_features = features.dtypes[features.dtypes == 'object'].index
numeric_features, non_numeric_features
# Out:
# (Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#         'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B', 'STORY', 'UNITS'],
#        dtype='object'),
#  Index(['NBHD', 'PROP_CLASS', 'STYLE_CN'], dtype='object'))

# %%
# If you want to drop the non-numeric features, you just set drop_non_numeric_features= True.
drop_non_numeric_features= False

if drop_non_numeric_features:
    features= features.drop(non_numeric_features, axis=1)
else:
    # One-hot encode categorical features
    features = pd.get_dummies(features, columns=non_numeric_features, dummy_na=True)

# Check for non-numeric columns
non_numeric_cols = features.select_dtypes(include=['object']).columns
if not non_numeric_cols.empty:
    raise ValueError(f"DataFrame contains non-numeric columns: {non_numeric_cols.tolist()}")

# %%
# Standardize numeric features
features[numeric_features] = features[numeric_features].apply(lambda x: (x - x.mean()) / (x.std()))

# %%
# recheck the mean and std after standardization
features[numeric_features].mean(), features[numeric_features].std()
# Out:
# (LIVING_SQFT   -6.919686e-17
#  FBSMT_SQFT    -7.907445e-17
#  BSMT_AREA      5.829929e-17
#  LAND_SQFT      1.792998e-17
#  GRD_AREA      -1.975519e-17
#  BLDG_AGE      -1.385011e-17
#  RM_AGE         2.795645e-17
#  BED_RMS        2.122341e-16
#  FULL_B         1.469829e-16
#  HLF_B         -5.658145e-17
#  STORY         -4.563020e-18
#  UNITS          5.017175e-16
#  dtype: float64,
#  LIVING_SQFT    1.0
#  FBSMT_SQFT     1.0
#  BSMT_AREA      1.0
#  LAND_SQFT      1.0
#  GRD_AREA       1.0
#  BLDG_AGE       1.0
#  RM_AGE         1.0
#  BED_RMS        1.0
#  FULL_B         1.0
#  HLF_B          1.0
#  STORY          1.0
#  UNITS          1.0
#  dtype: float64)

# %% [markdown]
# We see that after standardization, the features for the train data have mean 0 and standard deviation 1.

# %%
# After the feature standardization, we can impute the missing values with zeros.
features[numeric_features] = features[numeric_features].fillna(0)

# %% [markdown]
# Double check the features after data processing.

# %%
features.info()
print(features.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16545 entries, 0 to 4963
# Columns: 105 entries, LIVING_SQFT to STYLE_CN_nan
# dtypes: float64(12), uint8(93)
# memory usage: 3.1 MB
# Index(['LIVING_SQFT', 'FBSMT_SQFT', 'BSMT_AREA', 'LAND_SQFT', 'GRD_AREA',
#        'BLDG_AGE', 'RM_AGE', 'BED_RMS', 'FULL_B', 'HLF_B',
#        ...
#        'STYLE_CN_3 STORY', 'STYLE_CN_BI-LEVEL', 'STYLE_CN_CONVERSION',
#        'STYLE_CN_END UNIT', 'STYLE_CN_MIDDLE UNIT', 'STYLE_CN_RANCH',
#        'STYLE_CN_SPLIT LEVEL', 'STYLE_CN_TRI-LEVEL', 'STYLE_CN_TRI-LEVEL W/B',
#        'STYLE_CN_nan'],
#       dtype='object', length=105)

# %% [markdown]
# Note that after the one-hot encoding of the non-numeric features, now we have 105-dimensional feature.

# %%
# check whether there is any missing entry
print(features.isnull().sum())
# Out:
# LIVING_SQFT               0
# FBSMT_SQFT                0
# BSMT_AREA                 0
# LAND_SQFT                 0
# GRD_AREA                  0
#                          ..
# STYLE_CN_RANCH            0
# STYLE_CN_SPLIT LEVEL      0
# STYLE_CN_TRI-LEVEL        0
# STYLE_CN_TRI-LEVEL W/B    0
# STYLE_CN_nan              0
# Length: 105, dtype: int64

# %%
# we extract out the train and test features
train_features = features.iloc[:len(train_labels)]
test_features = features.iloc[len(train_labels):]
train_features.shape, test_features.shape
# Out:
# ((11581, 105), (4964, 105))

# %%
import torch
import numpy as np

# Convert training features and labels to PyTorch tensors
train_features = torch.tensor(train_features.values.astype(np.float32), dtype=torch.float32)
test_features = torch.tensor(test_features.values.astype(np.float32), dtype=torch.float32)
train_labels = torch.tensor(train_labels.values.reshape(-1, 1).astype(np.float32), dtype=torch.float32)

# %%
train_labels
# Out:
# tensor([[ 2.8500],
#         [12.3000],
#         [ 4.2000],
#         ...,
#         [ 6.0200],
#         [ 3.8370],
#         [ 5.5000]])

# %%
train_labels.shape
# Out:
# torch.Size([11581, 1])

# %% [markdown]
# ---
# ## Training and Validation
#
# To prevent overfitting, we'll split it our training data into training and validation. We will use validation set to select the appropriate model.
# One way is to use the [`train_test_split` function](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html). You're more than welcome to use your own way.

# %%
#TODO: filling in the missing code to split train data into train and validation
from sklearn.model_selection import train_test_split  # Importing train_test_split function from sklearn for splitting data into training set and validation set
# Splitting the training data: 20% is validation data
indices = range(len(train_features))
train_indices, valid_indices, train_features, valid_features, train_labels, valid_labels = train_test_split(indices,train_features, train_labels, test_size=0.20, random_state=42)

# %%
print(train_features.shape)
print(valid_features.shape)
# Out:
# torch.Size([9264, 105])
# torch.Size([2317, 105])

# %% [markdown]
# ---
# ## DataLoaders and Batching
#
# After creating training, test, and validation data, we can create DataLoaders for this data by following two steps:
# 1. Create a known format for accessing our data, using [TensorDataset](https://pytorch.org/docs/stable/data.html#torch.utils.data.TensorDataset) which takes in an input set of data and a target set of data with the same first dimension, and creates a dataset.
# 2. Create DataLoaders and batch our training, validation, and test Tensor datasets. Note that we will shuffle the train data, so the model will not learn a particular order. For valid and test data, we do not shuffle.

# %%
from torch.utils.data import TensorDataset, DataLoader
train_data = TensorDataset(train_features, train_labels)
train_loader = DataLoader(train_data, batch_size=128, shuffle=True)
#TODO: create dataloader for validation data
valid_data = TensorDataset(valid_features, valid_labels)
valid_loader = DataLoader(valid_data, batch_size=128, shuffle=False)

# %%
test_data = TensorDataset(test_features)
test_loader = DataLoader(test_data, batch_size=128, shuffle=False)

# %% [markdown]
# Let's take a batch to have a sanity check

# %%
# obtain one batch of training data
dataiter = iter(train_loader)
features, labels = next(dataiter)

print('Sample input size: ', features.size()) # batch_size, seq_length
print('Sample input: \n', features)
print()
print('Sample label size: ', labels.size()) # batch_size
print('Sample label: \n', labels)
# Out:
# Sample input size:  torch.Size([128, 105])
# Sample input:
#  tensor([[-0.9636, -0.6920, -0.8231,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.2833, -0.6920,  2.1687,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.1666, -0.6920, -0.8231,  ...,  1.0000,  0.0000,  0.0000],
#         ...,
#         [-0.2396,  1.9321,  1.4966,  ...,  0.0000,  0.0000,  0.0000],
#         [ 1.7763, -0.6920, -0.8231,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.5912,  0.7362,  0.5102,  ...,  0.0000,  0.0000,  0.0000]])
#
# Sample label size:  torch.Size([128, 1])
# Sample label:
#  tensor([[ 1.5100],
#         [ 4.0950],
#         [ 4.6500],
#         [ 6.4500],
#         [ 2.9100],
#         [ 3.5000],
#         [ 4.7500],
#         [ 9.2288],
#         [ 8.2500],
#         [ 2.3000],
#         [ 7.5100],
#         [ 3.0500],
#         [ 3.7400],
#         [ 6.9500],
#         [ 4.9000],
#         [ 6.6500],
#         [ 5.6000],
#         [10.7000],
#         [ 5.5000],
#         [ 3.0500],
#         [ 3.1400],
#         [ 4.9200],
#         [ 2.6281],
#         [ 4.3800],
#         [ 4.1190],
#         [ 3.9300],
#         [ 4.3900],
#         [ 3.8000],
#         [ 1.2750],
#         [ 9.2288],
#         [10.1000],
#         [ 2.2500],
#         [ 1.9450],
#         [ 6.3000],
#         [ 8.5000],
#         [ 2.7800],
#         [18.5000],
#         [ 7.2500],
#         [ 5.2500],
#         [ 7.9500],
#         [ 2.3500],
#         [ 8.1000],
#         [ 1.4700],
#         [ 9.5000],
#         [ 5.7490],
#         [ 6.4850],
#         [ 2.6800],
#         [ 7.5800],
#         [ 3.6000],
#         [ 4.4500],
#         [ 5.2593],
#         [ 3.3475],
#         [ 5.3400],
#         [ 5.5000],
#         [ 3.6800],
#         [ 3.9000],
#         [ 8.1300],
#         [ 5.1106],
#         [ 7.1000],
#         [ 4.2750],
#         [ 2.9000],
#         [ 5.5500],
#         [ 3.1000],
#         [ 8.0900],
#         [ 4.4500],
#         [ 7.5500],
#         [ 3.0000],
#         [ 4.6000],
#         [ 4.5000],
#         [ 5.2600],
#         [ 4.8500],
#         [ 8.6000],
#         [ 6.2309],
#         [ 4.4359],
#         [ 4.2900],
#         [ 2.4500],
#         [ 6.0000],
#         [ 3.9000],
#         [ 3.5000],
#         [ 1.9000],
#         [ 4.4500],
#         [ 4.4750],
#         [ 3.2458],
#         [ 2.9500],
#         [ 6.2500],
#         [ 8.6300],
#         [ 3.8400],
#         [ 3.5990],
#         [ 3.8264],
#         [ 7.2650],
#         [ 3.4000],
#         [ 2.5000],
#         [ 2.7915],
#         [ 2.2200],
#         [ 5.9000],
#         [ 8.6000],
#         [ 2.9700],
#         [ 5.1350],
#         [ 7.7359],
#         [ 2.7500],
#         [ 2.7000],
#         [ 2.5500],
#         [ 0.6217],
#         [ 5.3995],
#         [ 3.9000],
#         [ 2.7600],
#         [12.6500],
#         [ 3.3500],
#         [ 1.7500],
#         [ 1.7200],
#         [ 9.4914],
#         [ 7.3500],
#         [ 3.3000],
#         [ 4.3490],
#         [ 1.8500],
#         [ 5.4000],
#         [ 5.0800],
#         [ 6.3000],
#         [ 4.5000],
#         [ 2.1200],
#         [ 3.0260],
#         [ 1.3500],
#         [ 5.6500],
#         [ 4.8700],
#         [ 5.3500],
#         [ 5.1290],
#         [ 3.6500],
#         [ 5.2900]])

# %% [markdown]
# ---
# ## Linear Regression as Benchmark
#
# Let us build a linear regression model as a benchmark. Note that the linear regression model can be viewed as a special instance of multi-layer perception with no hidden layer and a single output neuron.

# %%
# Build a linear regression model network
import torch.nn as nn
lin_net = nn.Linear(train_features.shape[1], 1)

# %% [markdown]
# Let's print out the model achitecture.

# %%
lin_net
# Out:
# Linear(in_features=105, out_features=1, bias=True)

# %% [markdown]
# Let's take a batch and see the output

# %%
features, labels = next(dataiter)
output=lin_net(features)
output.shape,labels.shape
# Out:
# (torch.Size([128, 1]), torch.Size([128, 1]))

# %% [markdown]
# ---
# ## Train the model

# %% [markdown]
# First, we will use GPU training if it is availabe.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
lin_net = lin_net.to(device)

# %% [markdown]
# Second, let us specify the loss function.

# %%
#Since both the output and the label are real valued, we will use the standard mean-squared loss.
criterion = nn.MSELoss()

# %% [markdown]
# Third, while we are using the mean-squared loss for training loss, we will use
# a different metric to measure the predictive performance.
#
# Note that with house prices, as with stock prices, we care about relative quantities more than absolute quantities. Thus we tend to care more about the relative error than about the absolute error. For instance, if our prediction is off by \\$100,000 when estimating the sale price of a house which is \\$125,000, then we are probably doing a horrible job. On the other hand, if we err by this amount for a house with sale price \\$2 million, this might represent a pretty  accurate prediction.
#
# To address this issue, we will use the median error rate (MER) used by [Zestimate](https://www.zillow.com/z/zestimate/) to measure the predictive performance. The error rate is defined as
# $$
# \text{Error Rate} = \left| \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}} \right|
# $$
# The median error rate is defined as the median of error rates for all properties.

# %% [markdown]
# We are now ready to train the network. Let’s try training the model a bit longer: 200 epochs. To keep a record of how well the model does at each epoch, we will save the per-epoch training error and validation error in the training loop.

# %%
def train(model, train_loader, num_epochs, learning_rate=0.0005):
    train_losses = []                                       # To store training losses
    train_errors = []
    valid_losses = []                                       # To store validation loss
    valid_errors = []
    # Initialize the optimizer, we use Adam here
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    for epoch in range(num_epochs):
        tot_train_loss = 0.0                            # Store the total training MSE loss for this epoch
        train_error_rates =torch.tensor([]).to(device)  # Store the training error rates for this epoch
        for features, labels in train_loader:           # For each batch in DataLoader
            # Move data to device (GPU or CPU)
            features = features.to(device)
            labels = labels.to(device)

            output = model(features)  # Compute the output
            loss = criterion(output, labels)  # Compute loss
            optimizer.zero_grad()  # Clear the gradients from previous iteration
            loss.backward()  # Backpropagate the error
            optimizer.step()  # Update the weights

            tot_train_loss += loss.item()

            train_error_rate = torch.absolute(output/labels-1)
            train_error_rates= torch.cat((train_error_rates,train_error_rate),dim=0)

        train_loss =tot_train_loss /len(train_loader)
        train_error = torch.median(train_error_rates).item()
        train_losses.append(train_loss)
        train_errors.append(train_error)

        model.eval()
        tot_valid_loss = 0.0
        valid_error_rates = torch.tensor([]).to(device)

        with torch.no_grad():
          model.eval()
          for features, labels in valid_loader:
                features = features.to(device)
                labels = labels.to(device)

                # Forward pass
                log_ps = model(features)
                loss = criterion(log_ps, labels)
                tot_valid_loss += loss.item()

                valid_error_rate = torch.absolute(log_ps / labels - 1)
                valid_error_rates = torch.cat((valid_error_rates, valid_error_rate), dim=0)

        model.train()
        valid_loss = tot_valid_loss / len(valid_loader)
        valid_error = torch.median(valid_error_rates).item()
        valid_losses.append(valid_loss)
        valid_errors.append(valid_error)



        print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Train Loss: {:.3f}.. ".format(train_loss),
              "Train Median Error Rate: {:.3f}.. ".format(train_error),
              "Validatiion Loss: {:.3f}.. ".format(valid_loss),
              "Train Median Error Rate: {:.3f}.. ".format(valid_error),
              )

    return  train_losses,train_errors,valid_losses, valid_errors

# %%
train_losses, train_errors, valid_losses, valid_errors = train(lin_net, train_loader, num_epochs=200, learning_rate=0.003)
# Out:
# Epoch: 1/200..  Train Loss: 28.063..  Train Median Error Rate: 0.950..  Validatiion Loss: 24.454..  Train Median Error Rate: 0.856..
# Epoch: 2/200..  Train Loss: 20.169..  Train Median Error Rate: 0.789..  Validatiion Loss: 17.640..  Train Median Error Rate: 0.720..
# Epoch: 3/200..  Train Loss: 14.907..  Train Median Error Rate: 0.654..  Validatiion Loss: 13.019..  Train Median Error Rate: 0.595..
# Epoch: 4/200..  Train Loss: 11.053..  Train Median Error Rate: 0.533..  Validatiion Loss: 9.812..  Train Median Error Rate: 0.476..
# Epoch: 5/200..  Train Loss: 8.459..  Train Median Error Rate: 0.425..  Validatiion Loss: 7.623..  Train Median Error Rate: 0.376..
# Epoch: 6/200..  Train Loss: 6.639..  Train Median Error Rate: 0.333..  Validatiion Loss: 6.121..  Train Median Error Rate: 0.301..
# Epoch: 7/200..  Train Loss: 5.450..  Train Median Error Rate: 0.271..  Validatiion Loss: 5.122..  Train Median Error Rate: 0.256..
# Epoch: 8/200..  Train Loss: 4.634..  Train Median Error Rate: 0.233..  Validatiion Loss: 4.472..  Train Median Error Rate: 0.228..
# Epoch: 9/200..  Train Loss: 4.112..  Train Median Error Rate: 0.213..  Validatiion Loss: 4.018..  Train Median Error Rate: 0.208..
# Epoch: 10/200..  Train Loss: 3.762..  Train Median Error Rate: 0.199..  Validatiion Loss: 3.708..  Train Median Error Rate: 0.194..
# Epoch: 11/200..  Train Loss: 3.511..  Train Median Error Rate: 0.189..  Validatiion Loss: 3.475..  Train Median Error Rate: 0.185..
# Epoch: 12/200..  Train Loss: 3.342..  Train Median Error Rate: 0.180..  Validatiion Loss: 3.298..  Train Median Error Rate: 0.178..
# Epoch: 13/200..  Train Loss: 3.188..  Train Median Error Rate: 0.174..  Validatiion Loss: 3.163..  Train Median Error Rate: 0.170..
# Epoch: 14/200..  Train Loss: 3.060..  Train Median Error Rate: 0.168..  Validatiion Loss: 3.044..  Train Median Error Rate: 0.167..
# Epoch: 15/200..  Train Loss: 2.950..  Train Median Error Rate: 0.163..  Validatiion Loss: 2.951..  Train Median Error Rate: 0.161..
# Epoch: 16/200..  Train Loss: 2.888..  Train Median Error Rate: 0.157..  Validatiion Loss: 2.869..  Train Median Error Rate: 0.158..
# Epoch: 17/200..  Train Loss: 2.806..  Train Median Error Rate: 0.153..  Validatiion Loss: 2.797..  Train Median Error Rate: 0.152..
# Epoch: 18/200..  Train Loss: 2.757..  Train Median Error Rate: 0.149..  Validatiion Loss: 2.737..  Train Median Error Rate: 0.149..
# Epoch: 19/200..  Train Loss: 2.689..  Train Median Error Rate: 0.147..  Validatiion Loss: 2.685..  Train Median Error Rate: 0.147..
# Epoch: 20/200..  Train Loss: 2.642..  Train Median Error Rate: 0.145..  Validatiion Loss: 2.644..  Train Median Error Rate: 0.145..
# Epoch: 21/200..  Train Loss: 2.629..  Train Median Error Rate: 0.143..  Validatiion Loss: 2.601..  Train Median Error Rate: 0.144..
# Epoch: 22/200..  Train Loss: 2.586..  Train Median Error Rate: 0.140..  Validatiion Loss: 2.564..  Train Median Error Rate: 0.143..
# Epoch: 23/200..  Train Loss: 2.555..  Train Median Error Rate: 0.138..  Validatiion Loss: 2.536..  Train Median Error Rate: 0.140..
# Epoch: 24/200..  Train Loss: 2.543..  Train Median Error Rate: 0.138..  Validatiion Loss: 2.508..  Train Median Error Rate: 0.140..
# Epoch: 25/200..  Train Loss: 2.487..  Train Median Error Rate: 0.136..  Validatiion Loss: 2.483..  Train Median Error Rate: 0.140..
# Epoch: 26/200..  Train Loss: 2.464..  Train Median Error Rate: 0.136..  Validatiion Loss: 2.463..  Train Median Error Rate: 0.139..
# Epoch: 27/200..  Train Loss: 2.480..  Train Median Error Rate: 0.137..  Validatiion Loss: 2.450..  Train Median Error Rate: 0.137..
# Epoch: 28/200..  Train Loss: 2.439..  Train Median Error Rate: 0.134..  Validatiion Loss: 2.439..  Train Median Error Rate: 0.135..
# Epoch: 29/200..  Train Loss: 2.423..  Train Median Error Rate: 0.134..  Validatiion Loss: 2.418..  Train Median Error Rate: 0.137..
# Epoch: 30/200..  Train Loss: 2.410..  Train Median Error Rate: 0.134..  Validatiion Loss: 2.405..  Train Median Error Rate: 0.136..
# Epoch: 31/200..  Train Loss: 2.400..  Train Median Error Rate: 0.134..  Validatiion Loss: 2.404..  Train Median Error Rate: 0.134..
# Epoch: 32/200..  Train Loss: 2.393..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.390..  Train Median Error Rate: 0.136..
# Epoch: 33/200..  Train Loss: 2.384..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.380..  Train Median Error Rate: 0.136..
# Epoch: 34/200..  Train Loss: 2.385..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.373..  Train Median Error Rate: 0.136..
# Epoch: 35/200..  Train Loss: 2.361..  Train Median Error Rate: 0.134..  Validatiion Loss: 2.366..  Train Median Error Rate: 0.137..
# Epoch: 36/200..  Train Loss: 2.350..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.365..  Train Median Error Rate: 0.136..
# Epoch: 37/200..  Train Loss: 2.353..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.358..  Train Median Error Rate: 0.136..
# Epoch: 38/200..  Train Loss: 2.343..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.352..  Train Median Error Rate: 0.135..
# Epoch: 39/200..  Train Loss: 2.340..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.345..  Train Median Error Rate: 0.136..
# Epoch: 40/200..  Train Loss: 2.327..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.341..  Train Median Error Rate: 0.135..
# Epoch: 41/200..  Train Loss: 2.343..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.339..  Train Median Error Rate: 0.135..
# Epoch: 42/200..  Train Loss: 2.334..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.338..  Train Median Error Rate: 0.135..
# Epoch: 43/200..  Train Loss: 2.325..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.334..  Train Median Error Rate: 0.136..
# Epoch: 44/200..  Train Loss: 2.328..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.336..  Train Median Error Rate: 0.135..
# Epoch: 45/200..  Train Loss: 2.316..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.339..  Train Median Error Rate: 0.136..
# Epoch: 46/200..  Train Loss: 2.319..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.334..  Train Median Error Rate: 0.134..
# Epoch: 47/200..  Train Loss: 2.331..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.329..  Train Median Error Rate: 0.135..
# Epoch: 48/200..  Train Loss: 2.311..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.329..  Train Median Error Rate: 0.135..
# Epoch: 49/200..  Train Loss: 2.314..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.328..  Train Median Error Rate: 0.133..
# Epoch: 50/200..  Train Loss: 2.345..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.135..
# Epoch: 51/200..  Train Loss: 2.311..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.330..  Train Median Error Rate: 0.134..
# Epoch: 52/200..  Train Loss: 2.320..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.333..  Train Median Error Rate: 0.133..
# Epoch: 53/200..  Train Loss: 2.321..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.330..  Train Median Error Rate: 0.133..
# Epoch: 54/200..  Train Loss: 2.311..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.134..
# Epoch: 55/200..  Train Loss: 2.303..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.133..
# Epoch: 56/200..  Train Loss: 2.314..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.331..  Train Median Error Rate: 0.133..
# Epoch: 57/200..  Train Loss: 2.308..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.133..
# Epoch: 58/200..  Train Loss: 2.297..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.133..
# Epoch: 59/200..  Train Loss: 2.321..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.133..
# Epoch: 60/200..  Train Loss: 2.308..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 61/200..  Train Loss: 2.323..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 62/200..  Train Loss: 2.313..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.133..
# Epoch: 63/200..  Train Loss: 2.304..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 64/200..  Train Loss: 2.305..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 65/200..  Train Loss: 2.300..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.132..
# Epoch: 66/200..  Train Loss: 2.319..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.133..
# Epoch: 67/200..  Train Loss: 2.315..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.133..
# Epoch: 68/200..  Train Loss: 2.298..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.131..
# Epoch: 69/200..  Train Loss: 2.306..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.132..
# Epoch: 70/200..  Train Loss: 2.295..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.337..  Train Median Error Rate: 0.133..
# Epoch: 71/200..  Train Loss: 2.300..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 72/200..  Train Loss: 2.295..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 73/200..  Train Loss: 2.300..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.131..
# Epoch: 74/200..  Train Loss: 2.301..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.132..
# Epoch: 75/200..  Train Loss: 2.290..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.132..
# Epoch: 76/200..  Train Loss: 2.304..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 77/200..  Train Loss: 2.299..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.134..
# Epoch: 78/200..  Train Loss: 2.297..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.329..  Train Median Error Rate: 0.132..
# Epoch: 79/200..  Train Loss: 2.291..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 80/200..  Train Loss: 2.305..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.346..  Train Median Error Rate: 0.134..
# Epoch: 81/200..  Train Loss: 2.296..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.131..
# Epoch: 82/200..  Train Loss: 2.291..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.334..  Train Median Error Rate: 0.132..
# Epoch: 83/200..  Train Loss: 2.298..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 84/200..  Train Loss: 2.291..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.131..
# Epoch: 85/200..  Train Loss: 2.300..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.132..
# Epoch: 86/200..  Train Loss: 2.297..  Train Median Error Rate: 0.130..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 87/200..  Train Loss: 2.291..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.131..
# Epoch: 88/200..  Train Loss: 2.291..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.132..
# Epoch: 89/200..  Train Loss: 2.304..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.135..
# Epoch: 90/200..  Train Loss: 2.306..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.328..  Train Median Error Rate: 0.133..
# Epoch: 91/200..  Train Loss: 2.301..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 92/200..  Train Loss: 2.293..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.329..  Train Median Error Rate: 0.133..
# Epoch: 93/200..  Train Loss: 2.292..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.133..
# Epoch: 94/200..  Train Loss: 2.304..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.132..
# Epoch: 95/200..  Train Loss: 2.305..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.342..  Train Median Error Rate: 0.133..
# Epoch: 96/200..  Train Loss: 2.306..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 97/200..  Train Loss: 2.292..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.133..
# Epoch: 98/200..  Train Loss: 2.305..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.329..  Train Median Error Rate: 0.132..
# Epoch: 99/200..  Train Loss: 2.304..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 100/200..  Train Loss: 2.303..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.332..  Train Median Error Rate: 0.134..
# Epoch: 101/200..  Train Loss: 2.299..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 102/200..  Train Loss: 2.298..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.328..  Train Median Error Rate: 0.132..
# Epoch: 103/200..  Train Loss: 2.301..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 104/200..  Train Loss: 2.302..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 105/200..  Train Loss: 2.287..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.134..
# Epoch: 106/200..  Train Loss: 2.302..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.132..
# Epoch: 107/200..  Train Loss: 2.295..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.330..  Train Median Error Rate: 0.134..
# Epoch: 108/200..  Train Loss: 2.294..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 109/200..  Train Loss: 2.305..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.330..  Train Median Error Rate: 0.133..
# Epoch: 110/200..  Train Loss: 2.298..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 111/200..  Train Loss: 2.287..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 112/200..  Train Loss: 2.304..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 113/200..  Train Loss: 2.285..  Train Median Error Rate: 0.130..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.134..
# Epoch: 114/200..  Train Loss: 2.300..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.132..
# Epoch: 115/200..  Train Loss: 2.295..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 116/200..  Train Loss: 2.300..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 117/200..  Train Loss: 2.296..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 118/200..  Train Loss: 2.293..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.135..
# Epoch: 119/200..  Train Loss: 2.294..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.134..
# Epoch: 120/200..  Train Loss: 2.316..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.134..
# Epoch: 121/200..  Train Loss: 2.297..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.131..
# Epoch: 122/200..  Train Loss: 2.307..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.133..
# Epoch: 123/200..  Train Loss: 2.294..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 124/200..  Train Loss: 2.296..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.135..
# Epoch: 125/200..  Train Loss: 2.303..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 126/200..  Train Loss: 2.298..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.133..
# Epoch: 127/200..  Train Loss: 2.304..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.328..  Train Median Error Rate: 0.134..
# Epoch: 128/200..  Train Loss: 2.294..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 129/200..  Train Loss: 2.300..  Train Median Error Rate: 0.130..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.135..
# Epoch: 130/200..  Train Loss: 2.317..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 131/200..  Train Loss: 2.298..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.133..
# Epoch: 132/200..  Train Loss: 2.297..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.326..  Train Median Error Rate: 0.132..
# Epoch: 133/200..  Train Loss: 2.301..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.134..
# Epoch: 134/200..  Train Loss: 2.294..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 135/200..  Train Loss: 2.295..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.335..  Train Median Error Rate: 0.134..
# Epoch: 136/200..  Train Loss: 2.308..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.132..
# Epoch: 137/200..  Train Loss: 2.305..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.339..  Train Median Error Rate: 0.135..
# Epoch: 138/200..  Train Loss: 2.289..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 139/200..  Train Loss: 2.288..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 140/200..  Train Loss: 2.294..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.132..
# Epoch: 141/200..  Train Loss: 2.297..  Train Median Error Rate: 0.130..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.133..
# Epoch: 142/200..  Train Loss: 2.293..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.329..  Train Median Error Rate: 0.134..
# Epoch: 143/200..  Train Loss: 2.300..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.331..  Train Median Error Rate: 0.134..
# Epoch: 144/200..  Train Loss: 2.298..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.132..
# Epoch: 145/200..  Train Loss: 2.293..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 146/200..  Train Loss: 2.295..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.134..
# Epoch: 147/200..  Train Loss: 2.292..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.132..
# Epoch: 148/200..  Train Loss: 2.306..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.326..  Train Median Error Rate: 0.132..
# Epoch: 149/200..  Train Loss: 2.300..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.135..
# Epoch: 150/200..  Train Loss: 2.313..  Train Median Error Rate: 0.130..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.132..
# Epoch: 151/200..  Train Loss: 2.305..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 152/200..  Train Loss: 2.292..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 153/200..  Train Loss: 2.317..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.134..
# Epoch: 154/200..  Train Loss: 2.298..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 155/200..  Train Loss: 2.301..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 156/200..  Train Loss: 2.299..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.134..
# Epoch: 157/200..  Train Loss: 2.299..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.132..
# Epoch: 158/200..  Train Loss: 2.312..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 159/200..  Train Loss: 2.290..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 160/200..  Train Loss: 2.294..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.134..
# Epoch: 161/200..  Train Loss: 2.312..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.328..  Train Median Error Rate: 0.134..
# Epoch: 162/200..  Train Loss: 2.292..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.326..  Train Median Error Rate: 0.134..
# Epoch: 163/200..  Train Loss: 2.298..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 164/200..  Train Loss: 2.306..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.133..
# Epoch: 165/200..  Train Loss: 2.312..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 166/200..  Train Loss: 2.296..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 167/200..  Train Loss: 2.304..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.133..
# Epoch: 168/200..  Train Loss: 2.301..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.132..
# Epoch: 169/200..  Train Loss: 2.305..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 170/200..  Train Loss: 2.288..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.326..  Train Median Error Rate: 0.132..
# Epoch: 171/200..  Train Loss: 2.309..  Train Median Error Rate: 0.130..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.135..
# Epoch: 172/200..  Train Loss: 2.316..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.133..
# Epoch: 173/200..  Train Loss: 2.286..  Train Median Error Rate: 0.133..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.131..
# Epoch: 174/200..  Train Loss: 2.287..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 175/200..  Train Loss: 2.296..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.133..
# Epoch: 176/200..  Train Loss: 2.290..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.133..
# Epoch: 177/200..  Train Loss: 2.306..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.134..
# Epoch: 178/200..  Train Loss: 2.301..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 179/200..  Train Loss: 2.312..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.134..
# Epoch: 180/200..  Train Loss: 2.297..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.328..  Train Median Error Rate: 0.131..
# Epoch: 181/200..  Train Loss: 2.294..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.132..
# Epoch: 182/200..  Train Loss: 2.310..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.324..  Train Median Error Rate: 0.133..
# Epoch: 183/200..  Train Loss: 2.301..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.342..  Train Median Error Rate: 0.133..
# Epoch: 184/200..  Train Loss: 2.291..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.132..
# Epoch: 185/200..  Train Loss: 2.299..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.133..
# Epoch: 186/200..  Train Loss: 2.299..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.327..  Train Median Error Rate: 0.133..
# Epoch: 187/200..  Train Loss: 2.287..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.322..  Train Median Error Rate: 0.134..
# Epoch: 188/200..  Train Loss: 2.292..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.134..
# Epoch: 189/200..  Train Loss: 2.313..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.132..
# Epoch: 190/200..  Train Loss: 2.295..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.132..
# Epoch: 191/200..  Train Loss: 2.295..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 192/200..  Train Loss: 2.298..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.320..  Train Median Error Rate: 0.131..
# Epoch: 193/200..  Train Loss: 2.290..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.134..
# Epoch: 194/200..  Train Loss: 2.291..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.316..  Train Median Error Rate: 0.134..
# Epoch: 195/200..  Train Loss: 2.291..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 196/200..  Train Loss: 2.308..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.132..
# Epoch: 197/200..  Train Loss: 2.304..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 198/200..  Train Loss: 2.300..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.133..
# Epoch: 199/200..  Train Loss: 2.293..  Train Median Error Rate: 0.132..  Validatiion Loss: 2.325..  Train Median Error Rate: 0.134..
# Epoch: 200/200..  Train Loss: 2.296..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.318..  Train Median Error Rate: 0.131..

# %% [markdown]
# Define a function to plot errors.

# %%
#TODO: Write code to plot the training and vadliation errors (MER) over epochs
plt.plot(train_errors, label='Training loss')
plt.plot(valid_errors, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ---
# ## Build the Multi-layer Perceptron Base Model

# %% [markdown]
# In the following, we build a multi-layer perception model with 2 hidden layers of sizes 256 and 128, respectively and ReLu activations.

# %%
# Build a feed-forward network
import torch.nn as nn
model = nn.Sequential(nn.Linear(train_features.shape[1], 256),
                      nn.ReLU(),
                      nn.Linear(256, 128),
                      nn.ReLU(),
                      nn.Linear(128,1))

# %% [markdown]
# Let's print out the model achitecture.

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=105, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=128, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
model = model.to(device)

# %%
#TODO: write code to train the MLP network and save training and validation error.
train_losses, train_errors, valid_losses, valid_errors = train(model, train_loader, num_epochs=200, learning_rate=0.003)
# Out:
# Epoch: 1/200..  Train Loss: 5.688..  Train Median Error Rate: 0.213..  Validatiion Loss: 2.355..  Train Median Error Rate: 0.127..
# Epoch: 2/200..  Train Loss: 2.300..  Train Median Error Rate: 0.131..  Validatiion Loss: 2.173..  Train Median Error Rate: 0.124..
# Epoch: 3/200..  Train Loss: 2.100..  Train Median Error Rate: 0.121..  Validatiion Loss: 2.193..  Train Median Error Rate: 0.116..
# Epoch: 4/200..  Train Loss: 1.939..  Train Median Error Rate: 0.114..  Validatiion Loss: 1.981..  Train Median Error Rate: 0.117..
# Epoch: 5/200..  Train Loss: 1.861..  Train Median Error Rate: 0.116..  Validatiion Loss: 1.982..  Train Median Error Rate: 0.114..
# Epoch: 6/200..  Train Loss: 1.781..  Train Median Error Rate: 0.116..  Validatiion Loss: 2.201..  Train Median Error Rate: 0.119..
# Epoch: 7/200..  Train Loss: 1.727..  Train Median Error Rate: 0.111..  Validatiion Loss: 1.921..  Train Median Error Rate: 0.111..
# Epoch: 8/200..  Train Loss: 1.776..  Train Median Error Rate: 0.114..  Validatiion Loss: 1.954..  Train Median Error Rate: 0.110..
# Epoch: 9/200..  Train Loss: 1.613..  Train Median Error Rate: 0.104..  Validatiion Loss: 1.887..  Train Median Error Rate: 0.106..
# Epoch: 10/200..  Train Loss: 1.596..  Train Median Error Rate: 0.103..  Validatiion Loss: 2.024..  Train Median Error Rate: 0.133..
# Epoch: 11/200..  Train Loss: 1.501..  Train Median Error Rate: 0.101..  Validatiion Loss: 1.794..  Train Median Error Rate: 0.103..
# Epoch: 12/200..  Train Loss: 1.459..  Train Median Error Rate: 0.102..  Validatiion Loss: 1.788..  Train Median Error Rate: 0.106..
# Epoch: 13/200..  Train Loss: 1.494..  Train Median Error Rate: 0.104..  Validatiion Loss: 1.855..  Train Median Error Rate: 0.103..
# Epoch: 14/200..  Train Loss: 1.390..  Train Median Error Rate: 0.096..  Validatiion Loss: 1.938..  Train Median Error Rate: 0.100..
# Epoch: 15/200..  Train Loss: 1.388..  Train Median Error Rate: 0.099..  Validatiion Loss: 1.881..  Train Median Error Rate: 0.105..
# Epoch: 16/200..  Train Loss: 1.325..  Train Median Error Rate: 0.095..  Validatiion Loss: 1.892..  Train Median Error Rate: 0.112..
# Epoch: 17/200..  Train Loss: 1.386..  Train Median Error Rate: 0.104..  Validatiion Loss: 1.901..  Train Median Error Rate: 0.107..
# Epoch: 18/200..  Train Loss: 1.459..  Train Median Error Rate: 0.105..  Validatiion Loss: 1.921..  Train Median Error Rate: 0.100..
# Epoch: 19/200..  Train Loss: 1.299..  Train Median Error Rate: 0.095..  Validatiion Loss: 1.742..  Train Median Error Rate: 0.097..
# Epoch: 20/200..  Train Loss: 1.278..  Train Median Error Rate: 0.095..  Validatiion Loss: 1.935..  Train Median Error Rate: 0.115..
# Epoch: 21/200..  Train Loss: 1.312..  Train Median Error Rate: 0.098..  Validatiion Loss: 2.036..  Train Median Error Rate: 0.102..
# Epoch: 22/200..  Train Loss: 1.203..  Train Median Error Rate: 0.093..  Validatiion Loss: 1.839..  Train Median Error Rate: 0.101..
# Epoch: 23/200..  Train Loss: 1.201..  Train Median Error Rate: 0.094..  Validatiion Loss: 2.010..  Train Median Error Rate: 0.114..
# Epoch: 24/200..  Train Loss: 1.224..  Train Median Error Rate: 0.094..  Validatiion Loss: 1.904..  Train Median Error Rate: 0.107..
# Epoch: 25/200..  Train Loss: 1.195..  Train Median Error Rate: 0.092..  Validatiion Loss: 1.879..  Train Median Error Rate: 0.116..
# Epoch: 26/200..  Train Loss: 1.215..  Train Median Error Rate: 0.097..  Validatiion Loss: 1.870..  Train Median Error Rate: 0.106..
# Epoch: 27/200..  Train Loss: 1.125..  Train Median Error Rate: 0.091..  Validatiion Loss: 1.942..  Train Median Error Rate: 0.113..
# Epoch: 28/200..  Train Loss: 1.128..  Train Median Error Rate: 0.089..  Validatiion Loss: 1.946..  Train Median Error Rate: 0.108..
# Epoch: 29/200..  Train Loss: 1.107..  Train Median Error Rate: 0.091..  Validatiion Loss: 2.035..  Train Median Error Rate: 0.118..
# Epoch: 30/200..  Train Loss: 1.112..  Train Median Error Rate: 0.090..  Validatiion Loss: 1.841..  Train Median Error Rate: 0.096..
# Epoch: 31/200..  Train Loss: 1.161..  Train Median Error Rate: 0.096..  Validatiion Loss: 1.927..  Train Median Error Rate: 0.108..
# Epoch: 32/200..  Train Loss: 1.120..  Train Median Error Rate: 0.096..  Validatiion Loss: 2.181..  Train Median Error Rate: 0.126..
# Epoch: 33/200..  Train Loss: 1.085..  Train Median Error Rate: 0.092..  Validatiion Loss: 2.067..  Train Median Error Rate: 0.117..
# Epoch: 34/200..  Train Loss: 1.033..  Train Median Error Rate: 0.086..  Validatiion Loss: 1.943..  Train Median Error Rate: 0.097..
# Epoch: 35/200..  Train Loss: 1.043..  Train Median Error Rate: 0.087..  Validatiion Loss: 2.033..  Train Median Error Rate: 0.122..
# Epoch: 36/200..  Train Loss: 1.068..  Train Median Error Rate: 0.091..  Validatiion Loss: 1.986..  Train Median Error Rate: 0.104..
# Epoch: 37/200..  Train Loss: 1.055..  Train Median Error Rate: 0.088..  Validatiion Loss: 1.903..  Train Median Error Rate: 0.105..
# Epoch: 38/200..  Train Loss: 1.047..  Train Median Error Rate: 0.091..  Validatiion Loss: 1.901..  Train Median Error Rate: 0.104..
# Epoch: 39/200..  Train Loss: 0.994..  Train Median Error Rate: 0.089..  Validatiion Loss: 2.004..  Train Median Error Rate: 0.111..
# Epoch: 40/200..  Train Loss: 1.044..  Train Median Error Rate: 0.091..  Validatiion Loss: 2.265..  Train Median Error Rate: 0.108..
# Epoch: 41/200..  Train Loss: 0.951..  Train Median Error Rate: 0.086..  Validatiion Loss: 2.047..  Train Median Error Rate: 0.103..
# Epoch: 42/200..  Train Loss: 0.961..  Train Median Error Rate: 0.085..  Validatiion Loss: 1.925..  Train Median Error Rate: 0.099..
# Epoch: 43/200..  Train Loss: 0.920..  Train Median Error Rate: 0.084..  Validatiion Loss: 2.012..  Train Median Error Rate: 0.108..
# Epoch: 44/200..  Train Loss: 0.906..  Train Median Error Rate: 0.082..  Validatiion Loss: 2.066..  Train Median Error Rate: 0.104..
# Epoch: 45/200..  Train Loss: 0.930..  Train Median Error Rate: 0.085..  Validatiion Loss: 2.002..  Train Median Error Rate: 0.104..
# Epoch: 46/200..  Train Loss: 0.980..  Train Median Error Rate: 0.086..  Validatiion Loss: 2.340..  Train Median Error Rate: 0.113..
# Epoch: 47/200..  Train Loss: 0.985..  Train Median Error Rate: 0.088..  Validatiion Loss: 1.955..  Train Median Error Rate: 0.098..
# Epoch: 48/200..  Train Loss: 0.920..  Train Median Error Rate: 0.085..  Validatiion Loss: 1.989..  Train Median Error Rate: 0.109..
# Epoch: 49/200..  Train Loss: 0.913..  Train Median Error Rate: 0.086..  Validatiion Loss: 2.052..  Train Median Error Rate: 0.106..
# Epoch: 50/200..  Train Loss: 0.862..  Train Median Error Rate: 0.082..  Validatiion Loss: 2.050..  Train Median Error Rate: 0.102..
# Epoch: 51/200..  Train Loss: 0.886..  Train Median Error Rate: 0.082..  Validatiion Loss: 1.957..  Train Median Error Rate: 0.107..
# Epoch: 52/200..  Train Loss: 0.938..  Train Median Error Rate: 0.088..  Validatiion Loss: 2.084..  Train Median Error Rate: 0.116..
# Epoch: 53/200..  Train Loss: 0.868..  Train Median Error Rate: 0.081..  Validatiion Loss: 1.949..  Train Median Error Rate: 0.106..
# Epoch: 54/200..  Train Loss: 0.869..  Train Median Error Rate: 0.083..  Validatiion Loss: 2.048..  Train Median Error Rate: 0.103..
# Epoch: 55/200..  Train Loss: 0.796..  Train Median Error Rate: 0.078..  Validatiion Loss: 2.043..  Train Median Error Rate: 0.101..
# Epoch: 56/200..  Train Loss: 0.776..  Train Median Error Rate: 0.077..  Validatiion Loss: 2.033..  Train Median Error Rate: 0.099..
# Epoch: 57/200..  Train Loss: 0.787..  Train Median Error Rate: 0.077..  Validatiion Loss: 2.248..  Train Median Error Rate: 0.102..
# Epoch: 58/200..  Train Loss: 0.792..  Train Median Error Rate: 0.079..  Validatiion Loss: 2.165..  Train Median Error Rate: 0.112..
# Epoch: 59/200..  Train Loss: 0.751..  Train Median Error Rate: 0.080..  Validatiion Loss: 2.130..  Train Median Error Rate: 0.109..
# Epoch: 60/200..  Train Loss: 0.792..  Train Median Error Rate: 0.077..  Validatiion Loss: 2.058..  Train Median Error Rate: 0.106..
# Epoch: 61/200..  Train Loss: 0.792..  Train Median Error Rate: 0.078..  Validatiion Loss: 2.060..  Train Median Error Rate: 0.106..
# Epoch: 62/200..  Train Loss: 0.766..  Train Median Error Rate: 0.077..  Validatiion Loss: 2.152..  Train Median Error Rate: 0.103..
# Epoch: 63/200..  Train Loss: 0.759..  Train Median Error Rate: 0.081..  Validatiion Loss: 2.180..  Train Median Error Rate: 0.101..
# Epoch: 64/200..  Train Loss: 0.708..  Train Median Error Rate: 0.075..  Validatiion Loss: 2.032..  Train Median Error Rate: 0.101..
# Epoch: 65/200..  Train Loss: 0.699..  Train Median Error Rate: 0.076..  Validatiion Loss: 2.098..  Train Median Error Rate: 0.103..
# Epoch: 66/200..  Train Loss: 0.743..  Train Median Error Rate: 0.078..  Validatiion Loss: 2.075..  Train Median Error Rate: 0.104..
# Epoch: 67/200..  Train Loss: 0.738..  Train Median Error Rate: 0.077..  Validatiion Loss: 2.162..  Train Median Error Rate: 0.107..
# Epoch: 68/200..  Train Loss: 0.741..  Train Median Error Rate: 0.077..  Validatiion Loss: 2.151..  Train Median Error Rate: 0.111..
# Epoch: 69/200..  Train Loss: 0.689..  Train Median Error Rate: 0.076..  Validatiion Loss: 2.116..  Train Median Error Rate: 0.105..
# Epoch: 70/200..  Train Loss: 0.732..  Train Median Error Rate: 0.079..  Validatiion Loss: 2.052..  Train Median Error Rate: 0.095..
# Epoch: 71/200..  Train Loss: 0.662..  Train Median Error Rate: 0.073..  Validatiion Loss: 2.277..  Train Median Error Rate: 0.107..
# Epoch: 72/200..  Train Loss: 0.668..  Train Median Error Rate: 0.073..  Validatiion Loss: 2.151..  Train Median Error Rate: 0.102..
# Epoch: 73/200..  Train Loss: 0.696..  Train Median Error Rate: 0.073..  Validatiion Loss: 2.160..  Train Median Error Rate: 0.110..
# Epoch: 74/200..  Train Loss: 0.675..  Train Median Error Rate: 0.075..  Validatiion Loss: 2.130..  Train Median Error Rate: 0.105..
# Epoch: 75/200..  Train Loss: 0.652..  Train Median Error Rate: 0.072..  Validatiion Loss: 2.158..  Train Median Error Rate: 0.106..
# Epoch: 76/200..  Train Loss: 0.651..  Train Median Error Rate: 0.072..  Validatiion Loss: 2.167..  Train Median Error Rate: 0.101..
# Epoch: 77/200..  Train Loss: 0.644..  Train Median Error Rate: 0.071..  Validatiion Loss: 2.160..  Train Median Error Rate: 0.100..
# Epoch: 78/200..  Train Loss: 0.650..  Train Median Error Rate: 0.070..  Validatiion Loss: 2.173..  Train Median Error Rate: 0.105..
# Epoch: 79/200..  Train Loss: 0.605..  Train Median Error Rate: 0.070..  Validatiion Loss: 2.031..  Train Median Error Rate: 0.104..
# Epoch: 80/200..  Train Loss: 0.632..  Train Median Error Rate: 0.072..  Validatiion Loss: 2.246..  Train Median Error Rate: 0.103..
# Epoch: 81/200..  Train Loss: 0.688..  Train Median Error Rate: 0.078..  Validatiion Loss: 2.195..  Train Median Error Rate: 0.117..
# Epoch: 82/200..  Train Loss: 0.617..  Train Median Error Rate: 0.070..  Validatiion Loss: 2.138..  Train Median Error Rate: 0.110..
# Epoch: 83/200..  Train Loss: 0.671..  Train Median Error Rate: 0.075..  Validatiion Loss: 2.318..  Train Median Error Rate: 0.106..
# Epoch: 84/200..  Train Loss: 0.667..  Train Median Error Rate: 0.073..  Validatiion Loss: 2.288..  Train Median Error Rate: 0.115..
# Epoch: 85/200..  Train Loss: 0.615..  Train Median Error Rate: 0.071..  Validatiion Loss: 2.237..  Train Median Error Rate: 0.117..
# Epoch: 86/200..  Train Loss: 0.639..  Train Median Error Rate: 0.071..  Validatiion Loss: 2.169..  Train Median Error Rate: 0.108..
# Epoch: 87/200..  Train Loss: 0.615..  Train Median Error Rate: 0.067..  Validatiion Loss: 2.192..  Train Median Error Rate: 0.106..
# Epoch: 88/200..  Train Loss: 0.614..  Train Median Error Rate: 0.069..  Validatiion Loss: 2.177..  Train Median Error Rate: 0.107..
# Epoch: 89/200..  Train Loss: 0.612..  Train Median Error Rate: 0.071..  Validatiion Loss: 2.166..  Train Median Error Rate: 0.100..
# Epoch: 90/200..  Train Loss: 0.546..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.233..  Train Median Error Rate: 0.103..
# Epoch: 91/200..  Train Loss: 0.599..  Train Median Error Rate: 0.069..  Validatiion Loss: 2.275..  Train Median Error Rate: 0.103..
# Epoch: 92/200..  Train Loss: 0.567..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.176..  Train Median Error Rate: 0.103..
# Epoch: 93/200..  Train Loss: 0.564..  Train Median Error Rate: 0.069..  Validatiion Loss: 2.213..  Train Median Error Rate: 0.105..
# Epoch: 94/200..  Train Loss: 0.588..  Train Median Error Rate: 0.068..  Validatiion Loss: 2.244..  Train Median Error Rate: 0.110..
# Epoch: 95/200..  Train Loss: 0.549..  Train Median Error Rate: 0.068..  Validatiion Loss: 2.139..  Train Median Error Rate: 0.098..
# Epoch: 96/200..  Train Loss: 0.519..  Train Median Error Rate: 0.064..  Validatiion Loss: 2.168..  Train Median Error Rate: 0.103..
# Epoch: 97/200..  Train Loss: 0.550..  Train Median Error Rate: 0.068..  Validatiion Loss: 2.323..  Train Median Error Rate: 0.108..
# Epoch: 98/200..  Train Loss: 0.544..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.223..  Train Median Error Rate: 0.108..
# Epoch: 99/200..  Train Loss: 0.535..  Train Median Error Rate: 0.067..  Validatiion Loss: 2.278..  Train Median Error Rate: 0.099..
# Epoch: 100/200..  Train Loss: 0.518..  Train Median Error Rate: 0.063..  Validatiion Loss: 2.310..  Train Median Error Rate: 0.103..
# Epoch: 101/200..  Train Loss: 0.551..  Train Median Error Rate: 0.067..  Validatiion Loss: 2.045..  Train Median Error Rate: 0.103..
# Epoch: 102/200..  Train Loss: 0.533..  Train Median Error Rate: 0.065..  Validatiion Loss: 2.202..  Train Median Error Rate: 0.105..
# Epoch: 103/200..  Train Loss: 0.522..  Train Median Error Rate: 0.064..  Validatiion Loss: 2.139..  Train Median Error Rate: 0.099..
# Epoch: 104/200..  Train Loss: 0.489..  Train Median Error Rate: 0.063..  Validatiion Loss: 2.391..  Train Median Error Rate: 0.105..
# Epoch: 105/200..  Train Loss: 0.548..  Train Median Error Rate: 0.067..  Validatiion Loss: 2.155..  Train Median Error Rate: 0.099..
# Epoch: 106/200..  Train Loss: 0.514..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.175..  Train Median Error Rate: 0.100..
# Epoch: 107/200..  Train Loss: 0.535..  Train Median Error Rate: 0.065..  Validatiion Loss: 2.183..  Train Median Error Rate: 0.105..
# Epoch: 108/200..  Train Loss: 0.494..  Train Median Error Rate: 0.064..  Validatiion Loss: 2.247..  Train Median Error Rate: 0.101..
# Epoch: 109/200..  Train Loss: 0.485..  Train Median Error Rate: 0.063..  Validatiion Loss: 2.333..  Train Median Error Rate: 0.105..
# Epoch: 110/200..  Train Loss: 0.466..  Train Median Error Rate: 0.063..  Validatiion Loss: 2.167..  Train Median Error Rate: 0.100..
# Epoch: 111/200..  Train Loss: 0.501..  Train Median Error Rate: 0.063..  Validatiion Loss: 2.330..  Train Median Error Rate: 0.103..
# Epoch: 112/200..  Train Loss: 0.548..  Train Median Error Rate: 0.070..  Validatiion Loss: 2.184..  Train Median Error Rate: 0.103..
# Epoch: 113/200..  Train Loss: 0.532..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.184..  Train Median Error Rate: 0.105..
# Epoch: 114/200..  Train Loss: 0.470..  Train Median Error Rate: 0.062..  Validatiion Loss: 2.205..  Train Median Error Rate: 0.104..
# Epoch: 115/200..  Train Loss: 0.477..  Train Median Error Rate: 0.062..  Validatiion Loss: 1.997..  Train Median Error Rate: 0.105..
# Epoch: 116/200..  Train Loss: 0.534..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.191..  Train Median Error Rate: 0.100..
# Epoch: 117/200..  Train Loss: 0.464..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.282..  Train Median Error Rate: 0.107..
# Epoch: 118/200..  Train Loss: 0.459..  Train Median Error Rate: 0.061..  Validatiion Loss: 2.205..  Train Median Error Rate: 0.102..
# Epoch: 119/200..  Train Loss: 0.481..  Train Median Error Rate: 0.062..  Validatiion Loss: 2.219..  Train Median Error Rate: 0.099..
# Epoch: 120/200..  Train Loss: 0.497..  Train Median Error Rate: 0.063..  Validatiion Loss: 2.143..  Train Median Error Rate: 0.102..
# Epoch: 121/200..  Train Loss: 0.460..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.223..  Train Median Error Rate: 0.105..
# Epoch: 122/200..  Train Loss: 0.480..  Train Median Error Rate: 0.061..  Validatiion Loss: 2.292..  Train Median Error Rate: 0.102..
# Epoch: 123/200..  Train Loss: 0.457..  Train Median Error Rate: 0.060..  Validatiion Loss: 2.146..  Train Median Error Rate: 0.104..
# Epoch: 124/200..  Train Loss: 0.454..  Train Median Error Rate: 0.061..  Validatiion Loss: 2.179..  Train Median Error Rate: 0.106..
# Epoch: 125/200..  Train Loss: 0.434..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.131..  Train Median Error Rate: 0.100..
# Epoch: 126/200..  Train Loss: 0.450..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.212..  Train Median Error Rate: 0.100..
# Epoch: 127/200..  Train Loss: 0.429..  Train Median Error Rate: 0.058..  Validatiion Loss: 2.120..  Train Median Error Rate: 0.104..
# Epoch: 128/200..  Train Loss: 0.418..  Train Median Error Rate: 0.057..  Validatiion Loss: 2.311..  Train Median Error Rate: 0.102..
# Epoch: 129/200..  Train Loss: 0.485..  Train Median Error Rate: 0.062..  Validatiion Loss: 2.074..  Train Median Error Rate: 0.104..
# Epoch: 130/200..  Train Loss: 0.486..  Train Median Error Rate: 0.065..  Validatiion Loss: 2.176..  Train Median Error Rate: 0.108..
# Epoch: 131/200..  Train Loss: 0.458..  Train Median Error Rate: 0.061..  Validatiion Loss: 2.319..  Train Median Error Rate: 0.103..
# Epoch: 132/200..  Train Loss: 0.404..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.154..  Train Median Error Rate: 0.102..
# Epoch: 133/200..  Train Loss: 0.424..  Train Median Error Rate: 0.056..  Validatiion Loss: 2.076..  Train Median Error Rate: 0.104..
# Epoch: 134/200..  Train Loss: 0.475..  Train Median Error Rate: 0.060..  Validatiion Loss: 2.145..  Train Median Error Rate: 0.105..
# Epoch: 135/200..  Train Loss: 0.474..  Train Median Error Rate: 0.062..  Validatiion Loss: 2.193..  Train Median Error Rate: 0.102..
# Epoch: 136/200..  Train Loss: 0.443..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.380..  Train Median Error Rate: 0.103..
# Epoch: 137/200..  Train Loss: 0.446..  Train Median Error Rate: 0.058..  Validatiion Loss: 2.204..  Train Median Error Rate: 0.107..
# Epoch: 138/200..  Train Loss: 0.437..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.260..  Train Median Error Rate: 0.103..
# Epoch: 139/200..  Train Loss: 0.452..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.237..  Train Median Error Rate: 0.100..
# Epoch: 140/200..  Train Loss: 0.425..  Train Median Error Rate: 0.058..  Validatiion Loss: 2.299..  Train Median Error Rate: 0.102..
# Epoch: 141/200..  Train Loss: 0.478..  Train Median Error Rate: 0.057..  Validatiion Loss: 2.274..  Train Median Error Rate: 0.101..
# Epoch: 142/200..  Train Loss: 0.415..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.161..  Train Median Error Rate: 0.101..
# Epoch: 143/200..  Train Loss: 0.399..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.180..  Train Median Error Rate: 0.102..
# Epoch: 144/200..  Train Loss: 0.409..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.292..  Train Median Error Rate: 0.105..
# Epoch: 145/200..  Train Loss: 0.389..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.190..  Train Median Error Rate: 0.097..
# Epoch: 146/200..  Train Loss: 0.392..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.275..  Train Median Error Rate: 0.103..
# Epoch: 147/200..  Train Loss: 0.417..  Train Median Error Rate: 0.058..  Validatiion Loss: 2.425..  Train Median Error Rate: 0.104..
# Epoch: 148/200..  Train Loss: 0.439..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.362..  Train Median Error Rate: 0.101..
# Epoch: 149/200..  Train Loss: 0.449..  Train Median Error Rate: 0.060..  Validatiion Loss: 2.627..  Train Median Error Rate: 0.102..
# Epoch: 150/200..  Train Loss: 0.409..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.213..  Train Median Error Rate: 0.100..
# Epoch: 151/200..  Train Loss: 0.409..  Train Median Error Rate: 0.056..  Validatiion Loss: 2.264..  Train Median Error Rate: 0.099..
# Epoch: 152/200..  Train Loss: 0.424..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.193..  Train Median Error Rate: 0.103..
# Epoch: 153/200..  Train Loss: 0.411..  Train Median Error Rate: 0.056..  Validatiion Loss: 2.270..  Train Median Error Rate: 0.099..
# Epoch: 154/200..  Train Loss: 0.399..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.269..  Train Median Error Rate: 0.098..
# Epoch: 155/200..  Train Loss: 0.383..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.306..  Train Median Error Rate: 0.101..
# Epoch: 156/200..  Train Loss: 0.398..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.262..  Train Median Error Rate: 0.103..
# Epoch: 157/200..  Train Loss: 0.370..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.300..  Train Median Error Rate: 0.099..
# Epoch: 158/200..  Train Loss: 0.388..  Train Median Error Rate: 0.056..  Validatiion Loss: 2.463..  Train Median Error Rate: 0.101..
# Epoch: 159/200..  Train Loss: 0.506..  Train Median Error Rate: 0.062..  Validatiion Loss: 2.217..  Train Median Error Rate: 0.100..
# Epoch: 160/200..  Train Loss: 0.418..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.252..  Train Median Error Rate: 0.099..
# Epoch: 161/200..  Train Loss: 0.399..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.289..  Train Median Error Rate: 0.113..
# Epoch: 162/200..  Train Loss: 0.401..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.330..  Train Median Error Rate: 0.101..
# Epoch: 163/200..  Train Loss: 0.390..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.190..  Train Median Error Rate: 0.102..
# Epoch: 164/200..  Train Loss: 0.390..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.266..  Train Median Error Rate: 0.103..
# Epoch: 165/200..  Train Loss: 0.364..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.211..  Train Median Error Rate: 0.104..
# Epoch: 166/200..  Train Loss: 0.394..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.257..  Train Median Error Rate: 0.102..
# Epoch: 167/200..  Train Loss: 0.407..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.321..  Train Median Error Rate: 0.101..
# Epoch: 168/200..  Train Loss: 0.371..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.134..  Train Median Error Rate: 0.105..
# Epoch: 169/200..  Train Loss: 0.360..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.231..  Train Median Error Rate: 0.098..
# Epoch: 170/200..  Train Loss: 0.356..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.258..  Train Median Error Rate: 0.102..
# Epoch: 171/200..  Train Loss: 0.353..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.271..  Train Median Error Rate: 0.101..
# Epoch: 172/200..  Train Loss: 0.372..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.299..  Train Median Error Rate: 0.105..
# Epoch: 173/200..  Train Loss: 0.418..  Train Median Error Rate: 0.056..  Validatiion Loss: 2.285..  Train Median Error Rate: 0.098..
# Epoch: 174/200..  Train Loss: 0.382..  Train Median Error Rate: 0.051..  Validatiion Loss: 2.215..  Train Median Error Rate: 0.103..
# Epoch: 175/200..  Train Loss: 0.432..  Train Median Error Rate: 0.057..  Validatiion Loss: 2.269..  Train Median Error Rate: 0.106..
# Epoch: 176/200..  Train Loss: 0.359..  Train Median Error Rate: 0.051..  Validatiion Loss: 2.275..  Train Median Error Rate: 0.101..
# Epoch: 177/200..  Train Loss: 0.366..  Train Median Error Rate: 0.051..  Validatiion Loss: 2.257..  Train Median Error Rate: 0.101..
# Epoch: 178/200..  Train Loss: 0.345..  Train Median Error Rate: 0.048..  Validatiion Loss: 2.277..  Train Median Error Rate: 0.104..
# Epoch: 179/200..  Train Loss: 0.383..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.205..  Train Median Error Rate: 0.105..
# Epoch: 180/200..  Train Loss: 0.356..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.307..  Train Median Error Rate: 0.099..
# Epoch: 181/200..  Train Loss: 0.340..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.356..  Train Median Error Rate: 0.108..
# Epoch: 182/200..  Train Loss: 0.359..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.259..  Train Median Error Rate: 0.100..
# Epoch: 183/200..  Train Loss: 0.339..  Train Median Error Rate: 0.048..  Validatiion Loss: 2.250..  Train Median Error Rate: 0.099..
# Epoch: 184/200..  Train Loss: 0.356..  Train Median Error Rate: 0.050..  Validatiion Loss: 2.268..  Train Median Error Rate: 0.101..
# Epoch: 185/200..  Train Loss: 0.347..  Train Median Error Rate: 0.051..  Validatiion Loss: 2.231..  Train Median Error Rate: 0.099..
# Epoch: 186/200..  Train Loss: 0.342..  Train Median Error Rate: 0.050..  Validatiion Loss: 2.252..  Train Median Error Rate: 0.105..
# Epoch: 187/200..  Train Loss: 0.336..  Train Median Error Rate: 0.050..  Validatiion Loss: 2.281..  Train Median Error Rate: 0.097..
# Epoch: 188/200..  Train Loss: 0.336..  Train Median Error Rate: 0.048..  Validatiion Loss: 2.270..  Train Median Error Rate: 0.103..
# Epoch: 189/200..  Train Loss: 0.364..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.273..  Train Median Error Rate: 0.103..
# Epoch: 190/200..  Train Loss: 0.343..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.170..  Train Median Error Rate: 0.101..
# Epoch: 191/200..  Train Loss: 0.338..  Train Median Error Rate: 0.048..  Validatiion Loss: 2.287..  Train Median Error Rate: 0.101..
# Epoch: 192/200..  Train Loss: 0.343..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.249..  Train Median Error Rate: 0.102..
# Epoch: 193/200..  Train Loss: 0.336..  Train Median Error Rate: 0.050..  Validatiion Loss: 2.251..  Train Median Error Rate: 0.101..
# Epoch: 194/200..  Train Loss: 0.336..  Train Median Error Rate: 0.048..  Validatiion Loss: 2.448..  Train Median Error Rate: 0.101..
# Epoch: 195/200..  Train Loss: 0.336..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.169..  Train Median Error Rate: 0.099..
# Epoch: 196/200..  Train Loss: 0.321..  Train Median Error Rate: 0.047..  Validatiion Loss: 2.342..  Train Median Error Rate: 0.103..
# Epoch: 197/200..  Train Loss: 0.336..  Train Median Error Rate: 0.050..  Validatiion Loss: 2.254..  Train Median Error Rate: 0.100..
# Epoch: 198/200..  Train Loss: 0.334..  Train Median Error Rate: 0.048..  Validatiion Loss: 2.202..  Train Median Error Rate: 0.101..
# Epoch: 199/200..  Train Loss: 0.361..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.407..  Train Median Error Rate: 0.101..
# Epoch: 200/200..  Train Loss: 0.346..  Train Median Error Rate: 0.049..  Validatiion Loss: 2.266..  Train Median Error Rate: 0.105..

# %%
#TODO: Write code to plot the training and validation error (MER) over epochs
plt.plot(train_errors, label='Training loss')
plt.plot(valid_errors, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ---
# ## Change network architecture

# %% [markdown]
# In the following, build a MLP with 4 hidden layer of sizes 512, 256, 128, 64, respectively.

# %%
#TODO: building a MLP with 4 hidden layer of sizes 512, 256, 128, 64,
model = nn.Sequential(nn.Linear(train_features.shape[1], 512),
                      nn.ReLU(),
                      nn.Linear(512, 256),
                      nn.ReLU(),
                      nn.Linear(256,128),
                      nn.ReLU(),
                      nn.Linear(128,64),
                      nn.ReLU(),
                      nn.Linear(64,1))

# %%
model
model = model.to(device)

# %%
#TODO: plot the training and validation error (MER) over epochs
#TODO: write code to train the MLP network and save training and validation error.
train_losses, train_errors, valid_losses, valid_errors = train(model, train_loader, num_epochs=150, learning_rate=0.0005)


plt.plot(train_errors, label='Training loss')
plt.plot(valid_errors, label='Validation loss')
plt.legend(frameon=False)
# Out:
# Epoch: 1/150..  Train Loss: 11.816..  Train Median Error Rate: 0.394..  Validatiion Loss: 3.563..  Train Median Error Rate: 0.188..
# Epoch: 2/150..  Train Loss: 3.064..  Train Median Error Rate: 0.168..  Validatiion Loss: 2.636..  Train Median Error Rate: 0.152..
# Epoch: 3/150..  Train Loss: 2.428..  Train Median Error Rate: 0.137..  Validatiion Loss: 2.300..  Train Median Error Rate: 0.129..
# Epoch: 4/150..  Train Loss: 2.174..  Train Median Error Rate: 0.127..  Validatiion Loss: 2.255..  Train Median Error Rate: 0.138..
# Epoch: 5/150..  Train Loss: 2.025..  Train Median Error Rate: 0.121..  Validatiion Loss: 2.076..  Train Median Error Rate: 0.124..
# Epoch: 6/150..  Train Loss: 1.965..  Train Median Error Rate: 0.117..  Validatiion Loss: 2.061..  Train Median Error Rate: 0.128..
# Epoch: 7/150..  Train Loss: 1.862..  Train Median Error Rate: 0.111..  Validatiion Loss: 1.996..  Train Median Error Rate: 0.109..
# Epoch: 8/150..  Train Loss: 1.763..  Train Median Error Rate: 0.110..  Validatiion Loss: 2.054..  Train Median Error Rate: 0.116..
# Epoch: 9/150..  Train Loss: 1.708..  Train Median Error Rate: 0.107..  Validatiion Loss: 2.089..  Train Median Error Rate: 0.121..
# Epoch: 10/150..  Train Loss: 1.693..  Train Median Error Rate: 0.111..  Validatiion Loss: 2.108..  Train Median Error Rate: 0.122..
# Epoch: 11/150..  Train Loss: 1.633..  Train Median Error Rate: 0.106..  Validatiion Loss: 1.907..  Train Median Error Rate: 0.100..
# Epoch: 12/150..  Train Loss: 1.556..  Train Median Error Rate: 0.102..  Validatiion Loss: 1.842..  Train Median Error Rate: 0.102..
# Epoch: 13/150..  Train Loss: 1.533..  Train Median Error Rate: 0.100..  Validatiion Loss: 1.830..  Train Median Error Rate: 0.107..
# Epoch: 14/150..  Train Loss: 1.489..  Train Median Error Rate: 0.100..  Validatiion Loss: 1.977..  Train Median Error Rate: 0.103..
# Epoch: 15/150..  Train Loss: 1.424..  Train Median Error Rate: 0.097..  Validatiion Loss: 1.854..  Train Median Error Rate: 0.108..
# Epoch: 16/150..  Train Loss: 1.386..  Train Median Error Rate: 0.097..  Validatiion Loss: 1.847..  Train Median Error Rate: 0.102..
# Epoch: 17/150..  Train Loss: 1.349..  Train Median Error Rate: 0.094..  Validatiion Loss: 1.794..  Train Median Error Rate: 0.108..
# Epoch: 18/150..  Train Loss: 1.311..  Train Median Error Rate: 0.095..  Validatiion Loss: 1.710..  Train Median Error Rate: 0.099..
# Epoch: 19/150..  Train Loss: 1.313..  Train Median Error Rate: 0.098..  Validatiion Loss: 1.712..  Train Median Error Rate: 0.094..
# Epoch: 20/150..  Train Loss: 1.301..  Train Median Error Rate: 0.095..  Validatiion Loss: 1.904..  Train Median Error Rate: 0.115..
# Epoch: 21/150..  Train Loss: 1.253..  Train Median Error Rate: 0.097..  Validatiion Loss: 1.706..  Train Median Error Rate: 0.099..
# Epoch: 22/150..  Train Loss: 1.239..  Train Median Error Rate: 0.095..  Validatiion Loss: 1.715..  Train Median Error Rate: 0.102..
# Epoch: 23/150..  Train Loss: 1.152..  Train Median Error Rate: 0.088..  Validatiion Loss: 1.816..  Train Median Error Rate: 0.099..
# Epoch: 24/150..  Train Loss: 1.188..  Train Median Error Rate: 0.098..  Validatiion Loss: 1.776..  Train Median Error Rate: 0.093..
# Epoch: 25/150..  Train Loss: 1.115..  Train Median Error Rate: 0.090..  Validatiion Loss: 1.776..  Train Median Error Rate: 0.102..
# Epoch: 26/150..  Train Loss: 1.066..  Train Median Error Rate: 0.085..  Validatiion Loss: 1.840..  Train Median Error Rate: 0.099..
# Epoch: 27/150..  Train Loss: 1.049..  Train Median Error Rate: 0.088..  Validatiion Loss: 1.722..  Train Median Error Rate: 0.095..
# Epoch: 28/150..  Train Loss: 1.075..  Train Median Error Rate: 0.094..  Validatiion Loss: 1.721..  Train Median Error Rate: 0.105..
# Epoch: 29/150..  Train Loss: 0.996..  Train Median Error Rate: 0.085..  Validatiion Loss: 1.694..  Train Median Error Rate: 0.100..
# Epoch: 30/150..  Train Loss: 0.984..  Train Median Error Rate: 0.087..  Validatiion Loss: 1.917..  Train Median Error Rate: 0.138..
# Epoch: 31/150..  Train Loss: 0.973..  Train Median Error Rate: 0.087..  Validatiion Loss: 1.792..  Train Median Error Rate: 0.102..
# Epoch: 32/150..  Train Loss: 0.948..  Train Median Error Rate: 0.083..  Validatiion Loss: 1.824..  Train Median Error Rate: 0.100..
# Epoch: 33/150..  Train Loss: 0.991..  Train Median Error Rate: 0.092..  Validatiion Loss: 1.820..  Train Median Error Rate: 0.120..
# Epoch: 34/150..  Train Loss: 0.987..  Train Median Error Rate: 0.089..  Validatiion Loss: 1.771..  Train Median Error Rate: 0.098..
# Epoch: 35/150..  Train Loss: 0.887..  Train Median Error Rate: 0.084..  Validatiion Loss: 1.854..  Train Median Error Rate: 0.108..
# Epoch: 36/150..  Train Loss: 0.973..  Train Median Error Rate: 0.090..  Validatiion Loss: 1.763..  Train Median Error Rate: 0.102..
# Epoch: 37/150..  Train Loss: 0.889..  Train Median Error Rate: 0.084..  Validatiion Loss: 1.822..  Train Median Error Rate: 0.104..
# Epoch: 38/150..  Train Loss: 0.859..  Train Median Error Rate: 0.082..  Validatiion Loss: 1.830..  Train Median Error Rate: 0.099..
# Epoch: 39/150..  Train Loss: 0.863..  Train Median Error Rate: 0.081..  Validatiion Loss: 1.706..  Train Median Error Rate: 0.099..
# Epoch: 40/150..  Train Loss: 0.845..  Train Median Error Rate: 0.083..  Validatiion Loss: 1.817..  Train Median Error Rate: 0.108..
# Epoch: 41/150..  Train Loss: 0.779..  Train Median Error Rate: 0.078..  Validatiion Loss: 1.775..  Train Median Error Rate: 0.102..
# Epoch: 42/150..  Train Loss: 0.807..  Train Median Error Rate: 0.078..  Validatiion Loss: 1.928..  Train Median Error Rate: 0.119..
# Epoch: 43/150..  Train Loss: 0.781..  Train Median Error Rate: 0.080..  Validatiion Loss: 1.866..  Train Median Error Rate: 0.096..
# Epoch: 44/150..  Train Loss: 0.788..  Train Median Error Rate: 0.078..  Validatiion Loss: 1.850..  Train Median Error Rate: 0.101..
# Epoch: 45/150..  Train Loss: 0.746..  Train Median Error Rate: 0.078..  Validatiion Loss: 1.900..  Train Median Error Rate: 0.095..
# Epoch: 46/150..  Train Loss: 0.750..  Train Median Error Rate: 0.081..  Validatiion Loss: 1.928..  Train Median Error Rate: 0.100..
# Epoch: 47/150..  Train Loss: 0.732..  Train Median Error Rate: 0.076..  Validatiion Loss: 1.954..  Train Median Error Rate: 0.102..
# Epoch: 48/150..  Train Loss: 0.704..  Train Median Error Rate: 0.076..  Validatiion Loss: 2.104..  Train Median Error Rate: 0.103..
# Epoch: 49/150..  Train Loss: 0.744..  Train Median Error Rate: 0.081..  Validatiion Loss: 1.892..  Train Median Error Rate: 0.103..
# Epoch: 50/150..  Train Loss: 0.705..  Train Median Error Rate: 0.076..  Validatiion Loss: 1.939..  Train Median Error Rate: 0.102..
# Epoch: 51/150..  Train Loss: 0.650..  Train Median Error Rate: 0.073..  Validatiion Loss: 1.891..  Train Median Error Rate: 0.099..
# Epoch: 52/150..  Train Loss: 0.678..  Train Median Error Rate: 0.077..  Validatiion Loss: 1.850..  Train Median Error Rate: 0.096..
# Epoch: 53/150..  Train Loss: 0.675..  Train Median Error Rate: 0.075..  Validatiion Loss: 2.016..  Train Median Error Rate: 0.103..
# Epoch: 54/150..  Train Loss: 0.669..  Train Median Error Rate: 0.076..  Validatiion Loss: 1.884..  Train Median Error Rate: 0.102..
# Epoch: 55/150..  Train Loss: 0.639..  Train Median Error Rate: 0.073..  Validatiion Loss: 1.986..  Train Median Error Rate: 0.101..
# Epoch: 56/150..  Train Loss: 0.657..  Train Median Error Rate: 0.075..  Validatiion Loss: 1.934..  Train Median Error Rate: 0.099..
# Epoch: 57/150..  Train Loss: 0.626..  Train Median Error Rate: 0.074..  Validatiion Loss: 2.004..  Train Median Error Rate: 0.100..
# Epoch: 58/150..  Train Loss: 0.591..  Train Median Error Rate: 0.070..  Validatiion Loss: 1.857..  Train Median Error Rate: 0.094..
# Epoch: 59/150..  Train Loss: 0.643..  Train Median Error Rate: 0.075..  Validatiion Loss: 1.985..  Train Median Error Rate: 0.102..
# Epoch: 60/150..  Train Loss: 0.638..  Train Median Error Rate: 0.073..  Validatiion Loss: 1.931..  Train Median Error Rate: 0.099..
# Epoch: 61/150..  Train Loss: 0.577..  Train Median Error Rate: 0.068..  Validatiion Loss: 1.862..  Train Median Error Rate: 0.097..
# Epoch: 62/150..  Train Loss: 0.581..  Train Median Error Rate: 0.070..  Validatiion Loss: 1.938..  Train Median Error Rate: 0.103..
# Epoch: 63/150..  Train Loss: 0.606..  Train Median Error Rate: 0.072..  Validatiion Loss: 1.912..  Train Median Error Rate: 0.097..
# Epoch: 64/150..  Train Loss: 0.571..  Train Median Error Rate: 0.073..  Validatiion Loss: 1.935..  Train Median Error Rate: 0.095..
# Epoch: 65/150..  Train Loss: 0.567..  Train Median Error Rate: 0.070..  Validatiion Loss: 1.872..  Train Median Error Rate: 0.102..
# Epoch: 66/150..  Train Loss: 0.556..  Train Median Error Rate: 0.068..  Validatiion Loss: 1.917..  Train Median Error Rate: 0.096..
# Epoch: 67/150..  Train Loss: 0.526..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.081..  Train Median Error Rate: 0.111..
# Epoch: 68/150..  Train Loss: 0.547..  Train Median Error Rate: 0.072..  Validatiion Loss: 1.908..  Train Median Error Rate: 0.095..
# Epoch: 69/150..  Train Loss: 0.572..  Train Median Error Rate: 0.071..  Validatiion Loss: 2.013..  Train Median Error Rate: 0.098..
# Epoch: 70/150..  Train Loss: 0.560..  Train Median Error Rate: 0.071..  Validatiion Loss: 1.883..  Train Median Error Rate: 0.098..
# Epoch: 71/150..  Train Loss: 0.541..  Train Median Error Rate: 0.069..  Validatiion Loss: 1.848..  Train Median Error Rate: 0.092..
# Epoch: 72/150..  Train Loss: 0.524..  Train Median Error Rate: 0.067..  Validatiion Loss: 1.985..  Train Median Error Rate: 0.102..
# Epoch: 73/150..  Train Loss: 0.496..  Train Median Error Rate: 0.066..  Validatiion Loss: 2.032..  Train Median Error Rate: 0.102..
# Epoch: 74/150..  Train Loss: 0.543..  Train Median Error Rate: 0.067..  Validatiion Loss: 1.993..  Train Median Error Rate: 0.098..
# Epoch: 75/150..  Train Loss: 0.509..  Train Median Error Rate: 0.066..  Validatiion Loss: 1.954..  Train Median Error Rate: 0.106..
# Epoch: 76/150..  Train Loss: 0.509..  Train Median Error Rate: 0.066..  Validatiion Loss: 1.892..  Train Median Error Rate: 0.098..
# Epoch: 77/150..  Train Loss: 0.498..  Train Median Error Rate: 0.065..  Validatiion Loss: 1.975..  Train Median Error Rate: 0.100..
# Epoch: 78/150..  Train Loss: 0.506..  Train Median Error Rate: 0.066..  Validatiion Loss: 1.925..  Train Median Error Rate: 0.098..
# Epoch: 79/150..  Train Loss: 0.463..  Train Median Error Rate: 0.061..  Validatiion Loss: 1.947..  Train Median Error Rate: 0.094..
# Epoch: 80/150..  Train Loss: 0.495..  Train Median Error Rate: 0.066..  Validatiion Loss: 1.938..  Train Median Error Rate: 0.100..
# Epoch: 81/150..  Train Loss: 0.502..  Train Median Error Rate: 0.068..  Validatiion Loss: 2.047..  Train Median Error Rate: 0.096..
# Epoch: 82/150..  Train Loss: 0.503..  Train Median Error Rate: 0.069..  Validatiion Loss: 1.947..  Train Median Error Rate: 0.093..
# Epoch: 83/150..  Train Loss: 0.464..  Train Median Error Rate: 0.063..  Validatiion Loss: 1.951..  Train Median Error Rate: 0.100..
# Epoch: 84/150..  Train Loss: 0.452..  Train Median Error Rate: 0.062..  Validatiion Loss: 2.080..  Train Median Error Rate: 0.108..
# Epoch: 85/150..  Train Loss: 0.511..  Train Median Error Rate: 0.069..  Validatiion Loss: 1.897..  Train Median Error Rate: 0.101..
# Epoch: 86/150..  Train Loss: 0.552..  Train Median Error Rate: 0.071..  Validatiion Loss: 2.004..  Train Median Error Rate: 0.103..
# Epoch: 87/150..  Train Loss: 0.528..  Train Median Error Rate: 0.067..  Validatiion Loss: 1.920..  Train Median Error Rate: 0.100..
# Epoch: 88/150..  Train Loss: 0.478..  Train Median Error Rate: 0.067..  Validatiion Loss: 1.943..  Train Median Error Rate: 0.100..
# Epoch: 89/150..  Train Loss: 0.451..  Train Median Error Rate: 0.060..  Validatiion Loss: 1.928..  Train Median Error Rate: 0.094..
# Epoch: 90/150..  Train Loss: 0.450..  Train Median Error Rate: 0.061..  Validatiion Loss: 1.907..  Train Median Error Rate: 0.090..
# Epoch: 91/150..  Train Loss: 0.463..  Train Median Error Rate: 0.063..  Validatiion Loss: 1.939..  Train Median Error Rate: 0.097..
# Epoch: 92/150..  Train Loss: 0.458..  Train Median Error Rate: 0.063..  Validatiion Loss: 2.023..  Train Median Error Rate: 0.097..
# Epoch: 93/150..  Train Loss: 0.452..  Train Median Error Rate: 0.062..  Validatiion Loss: 1.992..  Train Median Error Rate: 0.100..
# Epoch: 94/150..  Train Loss: 0.447..  Train Median Error Rate: 0.062..  Validatiion Loss: 2.008..  Train Median Error Rate: 0.096..
# Epoch: 95/150..  Train Loss: 0.419..  Train Median Error Rate: 0.060..  Validatiion Loss: 2.002..  Train Median Error Rate: 0.098..
# Epoch: 96/150..  Train Loss: 0.406..  Train Median Error Rate: 0.057..  Validatiion Loss: 2.066..  Train Median Error Rate: 0.099..
# Epoch: 97/150..  Train Loss: 0.398..  Train Median Error Rate: 0.056..  Validatiion Loss: 1.970..  Train Median Error Rate: 0.095..
# Epoch: 98/150..  Train Loss: 0.431..  Train Median Error Rate: 0.061..  Validatiion Loss: 1.943..  Train Median Error Rate: 0.097..
# Epoch: 99/150..  Train Loss: 0.409..  Train Median Error Rate: 0.058..  Validatiion Loss: 1.916..  Train Median Error Rate: 0.099..
# Epoch: 100/150..  Train Loss: 0.408..  Train Median Error Rate: 0.059..  Validatiion Loss: 1.934..  Train Median Error Rate: 0.099..
# Epoch: 101/150..  Train Loss: 0.393..  Train Median Error Rate: 0.057..  Validatiion Loss: 2.002..  Train Median Error Rate: 0.101..
# Epoch: 102/150..  Train Loss: 0.437..  Train Median Error Rate: 0.061..  Validatiion Loss: 2.003..  Train Median Error Rate: 0.096..
# Epoch: 103/150..  Train Loss: 0.454..  Train Median Error Rate: 0.066..  Validatiion Loss: 1.977..  Train Median Error Rate: 0.097..
# Epoch: 104/150..  Train Loss: 0.403..  Train Median Error Rate: 0.058..  Validatiion Loss: 1.950..  Train Median Error Rate: 0.096..
# Epoch: 105/150..  Train Loss: 0.386..  Train Median Error Rate: 0.056..  Validatiion Loss: 1.948..  Train Median Error Rate: 0.099..
# Epoch: 106/150..  Train Loss: 0.415..  Train Median Error Rate: 0.059..  Validatiion Loss: 2.051..  Train Median Error Rate: 0.100..
# Epoch: 107/150..  Train Loss: 0.394..  Train Median Error Rate: 0.057..  Validatiion Loss: 1.998..  Train Median Error Rate: 0.103..
# Epoch: 108/150..  Train Loss: 0.422..  Train Median Error Rate: 0.058..  Validatiion Loss: 2.047..  Train Median Error Rate: 0.096..
# Epoch: 109/150..  Train Loss: 0.393..  Train Median Error Rate: 0.057..  Validatiion Loss: 1.947..  Train Median Error Rate: 0.096..
# Epoch: 110/150..  Train Loss: 0.411..  Train Median Error Rate: 0.060..  Validatiion Loss: 1.933..  Train Median Error Rate: 0.097..
# Epoch: 111/150..  Train Loss: 0.400..  Train Median Error Rate: 0.058..  Validatiion Loss: 2.037..  Train Median Error Rate: 0.096..
# Epoch: 112/150..  Train Loss: 0.385..  Train Median Error Rate: 0.056..  Validatiion Loss: 1.954..  Train Median Error Rate: 0.096..
# Epoch: 113/150..  Train Loss: 0.367..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.106..  Train Median Error Rate: 0.095..
# Epoch: 114/150..  Train Loss: 0.379..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.066..  Train Median Error Rate: 0.101..
# Epoch: 115/150..  Train Loss: 0.373..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.008..  Train Median Error Rate: 0.099..
# Epoch: 116/150..  Train Loss: 0.404..  Train Median Error Rate: 0.057..  Validatiion Loss: 2.015..  Train Median Error Rate: 0.101..
# Epoch: 117/150..  Train Loss: 0.372..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.044..  Train Median Error Rate: 0.096..
# Epoch: 118/150..  Train Loss: 0.371..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.042..  Train Median Error Rate: 0.103..
# Epoch: 119/150..  Train Loss: 0.374..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.021..  Train Median Error Rate: 0.096..
# Epoch: 120/150..  Train Loss: 0.366..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.151..  Train Median Error Rate: 0.113..
# Epoch: 121/150..  Train Loss: 0.398..  Train Median Error Rate: 0.058..  Validatiion Loss: 2.085..  Train Median Error Rate: 0.101..
# Epoch: 122/150..  Train Loss: 0.417..  Train Median Error Rate: 0.061..  Validatiion Loss: 2.027..  Train Median Error Rate: 0.094..
# Epoch: 123/150..  Train Loss: 0.393..  Train Median Error Rate: 0.057..  Validatiion Loss: 1.950..  Train Median Error Rate: 0.098..
# Epoch: 124/150..  Train Loss: 0.411..  Train Median Error Rate: 0.060..  Validatiion Loss: 2.054..  Train Median Error Rate: 0.097..
# Epoch: 125/150..  Train Loss: 0.438..  Train Median Error Rate: 0.062..  Validatiion Loss: 1.981..  Train Median Error Rate: 0.096..
# Epoch: 126/150..  Train Loss: 0.403..  Train Median Error Rate: 0.059..  Validatiion Loss: 1.986..  Train Median Error Rate: 0.097..
# Epoch: 127/150..  Train Loss: 0.357..  Train Median Error Rate: 0.054..  Validatiion Loss: 1.985..  Train Median Error Rate: 0.100..
# Epoch: 128/150..  Train Loss: 0.362..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.057..  Train Median Error Rate: 0.097..
# Epoch: 129/150..  Train Loss: 0.358..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.142..  Train Median Error Rate: 0.096..
# Epoch: 130/150..  Train Loss: 0.365..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.053..  Train Median Error Rate: 0.099..
# Epoch: 131/150..  Train Loss: 0.373..  Train Median Error Rate: 0.058..  Validatiion Loss: 1.990..  Train Median Error Rate: 0.099..
# Epoch: 132/150..  Train Loss: 0.363..  Train Median Error Rate: 0.053..  Validatiion Loss: 2.077..  Train Median Error Rate: 0.113..
# Epoch: 133/150..  Train Loss: 0.373..  Train Median Error Rate: 0.054..  Validatiion Loss: 1.961..  Train Median Error Rate: 0.100..
# Epoch: 134/150..  Train Loss: 0.339..  Train Median Error Rate: 0.051..  Validatiion Loss: 1.929..  Train Median Error Rate: 0.096..
# Epoch: 135/150..  Train Loss: 0.380..  Train Median Error Rate: 0.056..  Validatiion Loss: 2.078..  Train Median Error Rate: 0.106..
# Epoch: 136/150..  Train Loss: 0.366..  Train Median Error Rate: 0.055..  Validatiion Loss: 2.000..  Train Median Error Rate: 0.099..
# Epoch: 137/150..  Train Loss: 0.375..  Train Median Error Rate: 0.056..  Validatiion Loss: 1.969..  Train Median Error Rate: 0.100..
# Epoch: 138/150..  Train Loss: 0.357..  Train Median Error Rate: 0.054..  Validatiion Loss: 1.928..  Train Median Error Rate: 0.098..
# Epoch: 139/150..  Train Loss: 0.379..  Train Median Error Rate: 0.053..  Validatiion Loss: 1.981..  Train Median Error Rate: 0.096..
# Epoch: 140/150..  Train Loss: 0.394..  Train Median Error Rate: 0.058..  Validatiion Loss: 1.995..  Train Median Error Rate: 0.102..
# Epoch: 141/150..  Train Loss: 0.345..  Train Median Error Rate: 0.051..  Validatiion Loss: 1.944..  Train Median Error Rate: 0.097..
# Epoch: 142/150..  Train Loss: 0.346..  Train Median Error Rate: 0.054..  Validatiion Loss: 2.054..  Train Median Error Rate: 0.099..
# Epoch: 143/150..  Train Loss: 0.338..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.063..  Train Median Error Rate: 0.109..
# Epoch: 144/150..  Train Loss: 0.355..  Train Median Error Rate: 0.054..  Validatiion Loss: 1.976..  Train Median Error Rate: 0.098..
# Epoch: 145/150..  Train Loss: 0.322..  Train Median Error Rate: 0.051..  Validatiion Loss: 2.028..  Train Median Error Rate: 0.100..
# Epoch: 146/150..  Train Loss: 0.360..  Train Median Error Rate: 0.053..  Validatiion Loss: 1.952..  Train Median Error Rate: 0.095..
# Epoch: 147/150..  Train Loss: 0.345..  Train Median Error Rate: 0.052..  Validatiion Loss: 2.033..  Train Median Error Rate: 0.097..
# Epoch: 148/150..  Train Loss: 0.326..  Train Median Error Rate: 0.048..  Validatiion Loss: 2.076..  Train Median Error Rate: 0.097..
# Epoch: 149/150..  Train Loss: 0.315..  Train Median Error Rate: 0.047..  Validatiion Loss: 1.987..  Train Median Error Rate: 0.098..
# Epoch: 150/150..  Train Loss: 0.315..  Train Median Error Rate: 0.047..  Validatiion Loss: 1.981..  Train Median Error Rate: 0.099..

# %% [markdown]
# ---
# ## Add norm regularization
#
# In the following, use the norm regularization to retrain the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization
def train_norm(model, train_loader, num_epochs, learning_rate=0.003):
    train_losses = []
    train_errors = []
    validation_errors = []

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0.000001)
    for epoch in range(num_epochs):
        tot_train_loss = 0.0                            # Store the total training MSE loss for this epoch
        train_error_rates =torch.tensor([]).to(device)  # Store the training error rates for this epoch
        validation_error_rates =torch.tensor([]).to(device)
        for features, labels in train_loader:           # For each batch in DataLoader
            # Move data to device (GPU or CPU)
            features = features.to(device)
            labels = labels.to(device)

            output = model(features)  # Compute the output
            loss = criterion(output, labels)  # Compute loss
            optimizer.zero_grad()  # Clear the gradients from previous iteration
            loss.backward()  # Backpropagate the error
            optimizer.step()  # Update the weights

            tot_train_loss += loss.item()


            train_error_rate = torch.absolute(output/labels-1)
            train_error_rates= torch.cat((train_error_rates,train_error_rate),dim=0)

        with torch.no_grad():
            model.eval()
            # validation pass here
            for features, labels in valid_loader:
              features = features.to(device)
              labels = labels.to(device)

              output = model(features)  # Compute the output
              loss = criterion(output, labels)  # Compute loss
              validation_error_rate = torch.absolute(output/labels-1)
              validation_error_rates= torch.cat((validation_error_rates,validation_error_rate),dim=0)

        model.train()
        train_loss = tot_train_loss /len(train_loader)
        train_error = torch.median(train_error_rates).item()
        validation_error = torch.median(validation_error_rates).item()
        train_losses.append(train_loss)
        train_errors.append(train_error)
        validation_errors.append(validation_error)
        # Print the training loss and validation loss every 10 epochs
        if epoch % 10 == 0:
            print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Train Loss: {:.3f}.. ".format(train_loss),
              "Train MER: {:.3f}.. ".format(train_error),
              "Validation MER: {:.3f}.. ".format(validation_error),
              )

    return  train_losses,train_errors,validation_errors

# %%
train_losses, train_errors, validation_errors = train_norm(model, train_loader, num_epochs=200, learning_rate=0.003)
# Out:
# Epoch: 1/200..  Train Loss: 1.467..  Train MER: 0.116..  Validation MER: 0.121..
# Epoch: 11/200..  Train Loss: 0.902..  Train MER: 0.092..  Validation MER: 0.112..
# Epoch: 21/200..  Train Loss: 0.874..  Train MER: 0.089..  Validation MER: 0.099..
# Epoch: 31/200..  Train Loss: 0.731..  Train MER: 0.084..  Validation MER: 0.105..
# Epoch: 41/200..  Train Loss: 0.739..  Train MER: 0.082..  Validation MER: 0.111..
# Epoch: 51/200..  Train Loss: 0.645..  Train MER: 0.079..  Validation MER: 0.103..
# Epoch: 61/200..  Train Loss: 0.584..  Train MER: 0.074..  Validation MER: 0.101..
# Epoch: 71/200..  Train Loss: 0.597..  Train MER: 0.078..  Validation MER: 0.101..
# Epoch: 81/200..  Train Loss: 0.521..  Train MER: 0.070..  Validation MER: 0.102..
# Epoch: 91/200..  Train Loss: 0.482..  Train MER: 0.069..  Validation MER: 0.103..
# Epoch: 101/200..  Train Loss: 0.490..  Train MER: 0.071..  Validation MER: 0.098..
# Epoch: 111/200..  Train Loss: 0.481..  Train MER: 0.070..  Validation MER: 0.102..
# Epoch: 121/200..  Train Loss: 0.519..  Train MER: 0.070..  Validation MER: 0.099..
# Epoch: 131/200..  Train Loss: 0.444..  Train MER: 0.068..  Validation MER: 0.102..
# Epoch: 141/200..  Train Loss: 0.514..  Train MER: 0.074..  Validation MER: 0.105..
# Epoch: 151/200..  Train Loss: 0.460..  Train MER: 0.065..  Validation MER: 0.100..
# Epoch: 161/200..  Train Loss: 0.553..  Train MER: 0.074..  Validation MER: 0.098..
# Epoch: 171/200..  Train Loss: 0.413..  Train MER: 0.063..  Validation MER: 0.114..
# Epoch: 181/200..  Train Loss: 0.404..  Train MER: 0.065..  Validation MER: 0.106..
# Epoch: 191/200..  Train Loss: 0.432..  Train MER: 0.067..  Validation MER: 0.105..

# %%
plt.plot(train_errors, label='Training loss')
plt.plot(validation_errors, label='Validation loss')
plt.legend(frameon=False)

# %% [markdown]
# ---
# ## Add dropout layer
#
# In the following, add dropout layer to the above MLP.

# %%
#TODO: plot the training and validation error (MER) over epochs after using norm regularization
dropout_rate = 0.20
model = nn.Sequential(nn.Linear(train_features.shape[1], 512),
                      nn.ReLU(),
                      nn.Dropout(dropout_rate),
                      nn.Linear(512, 256),
                      nn.ReLU(),
                      nn.Dropout(dropout_rate),
                      nn.Linear(256,128),
                      nn.ReLU(),
                      nn.Dropout(dropout_rate),
                      nn.Linear(128,64),
                      nn.ReLU(),
                      nn.Dropout(dropout_rate),
                      nn.Linear(64,1))

model = model.to(device)

train_losses, train_errors, validation_errors = train_norm(model,train_loader, num_epochs=200, learning_rate=0.003)

plt.plot(train_errors, label='Training error')
plt.plot(validation_errors, label='Validation error')
plt.legend(frameon=False)
# Out:
# Epoch: 1/200..  Train Loss: 6.476..  Train MER: 0.257..  Validation MER: 0.195..
# Epoch: 11/200..  Train Loss: 2.333..  Train MER: 0.148..  Validation MER: 0.116..
# Epoch: 21/200..  Train Loss: 1.971..  Train MER: 0.132..  Validation MER: 0.113..
# Epoch: 31/200..  Train Loss: 1.769..  Train MER: 0.123..  Validation MER: 0.116..
# Epoch: 41/200..  Train Loss: 1.599..  Train MER: 0.119..  Validation MER: 0.107..
# Epoch: 51/200..  Train Loss: 1.528..  Train MER: 0.116..  Validation MER: 0.099..
# Epoch: 61/200..  Train Loss: 1.360..  Train MER: 0.114..  Validation MER: 0.095..
# Epoch: 71/200..  Train Loss: 1.290..  Train MER: 0.109..  Validation MER: 0.097..
# Epoch: 81/200..  Train Loss: 1.248..  Train MER: 0.106..  Validation MER: 0.098..
# Epoch: 91/200..  Train Loss: 1.299..  Train MER: 0.111..  Validation MER: 0.110..
# Epoch: 101/200..  Train Loss: 1.177..  Train MER: 0.103..  Validation MER: 0.103..
# Epoch: 111/200..  Train Loss: 1.150..  Train MER: 0.103..  Validation MER: 0.109..
# Epoch: 121/200..  Train Loss: 1.183..  Train MER: 0.106..  Validation MER: 0.099..
# Epoch: 131/200..  Train Loss: 1.154..  Train MER: 0.106..  Validation MER: 0.106..
# Epoch: 141/200..  Train Loss: 1.102..  Train MER: 0.102..  Validation MER: 0.104..
# Epoch: 151/200..  Train Loss: 1.207..  Train MER: 0.105..  Validation MER: 0.108..
# Epoch: 161/200..  Train Loss: 1.005..  Train MER: 0.100..  Validation MER: 0.100..
# Epoch: 171/200..  Train Loss: 1.067..  Train MER: 0.103..  Validation MER: 0.095..
# Epoch: 181/200..  Train Loss: 1.011..  Train MER: 0.102..  Validation MER: 0.098..
# Epoch: 191/200..  Train Loss: 0.988..  Train MER: 0.100..  Validation MER: 0.098..

# %% [markdown]
# ## Some other model variations
#
# **You're more than welcome to try some other model varations (e.g. different number of hidden layers, hidden neurons, learning rate, etc) to achieve lower valid error. Include a table listing all the model hyperparameters that you have tried with the corresponding validation errors that you found.**

# %%
dropout_rate: 0.25
model = nn.Sequential(
      nn.Linear(train_features.shape[1], 512),
      nn.ReLU(),
      nn.Dropout(dropout_rate),
      nn.Linear(512, 256),
      nn.ReLU(),
      nn.Dropout(dropout_rate),
      nn.Linear(256, 128),
      nn.ReLU(),
      nn.Dropout(dropout_rate),
      nn.Linear(128, 64),
      nn.ReLU(),
      nn.Dropout(dropout_rate),
      nn.Linear(64, 32),
      nn.ReLU(),
      nn.Dropout(dropout_rate),
      nn.Linear(32, 16),
      nn.ReLU(),
      nn.Dropout(dropout_rate),
      nn.Linear(16, 8),
      nn.ReLU(),
      nn.Dropout(dropout_rate),
      nn.Linear(8, 1)
  )
model = model.to(device)

train_losses, train_errors, validation_errors = train_norm(model,train_loader, num_epochs=160, learning_rate=0.003)
# Out:
# Epoch: 1/160..  Train Loss: 10.819..  Train MER: 0.413..  Validation MER: 0.186..
# Epoch: 11/160..  Train Loss: 3.373..  Train MER: 0.183..  Validation MER: 0.131..
# Epoch: 21/160..  Train Loss: 2.717..  Train MER: 0.157..  Validation MER: 0.115..
# Epoch: 31/160..  Train Loss: 2.833..  Train MER: 0.161..  Validation MER: 0.114..
# Epoch: 41/160..  Train Loss: 2.280..  Train MER: 0.143..  Validation MER: 0.111..
# Epoch: 51/160..  Train Loss: 2.178..  Train MER: 0.140..  Validation MER: 0.109..
# Epoch: 61/160..  Train Loss: 2.220..  Train MER: 0.141..  Validation MER: 0.119..
# Epoch: 71/160..  Train Loss: 1.983..  Train MER: 0.141..  Validation MER: 0.114..
# Epoch: 81/160..  Train Loss: 1.947..  Train MER: 0.141..  Validation MER: 0.117..
# Epoch: 91/160..  Train Loss: 1.891..  Train MER: 0.137..  Validation MER: 0.115..
# Epoch: 101/160..  Train Loss: 1.957..  Train MER: 0.139..  Validation MER: 0.122..
# Epoch: 111/160..  Train Loss: 1.942..  Train MER: 0.141..  Validation MER: 0.119..
# Epoch: 121/160..  Train Loss: 1.907..  Train MER: 0.136..  Validation MER: 0.114..
# Epoch: 131/160..  Train Loss: 1.834..  Train MER: 0.139..  Validation MER: 0.114..
# Epoch: 141/160..  Train Loss: 1.712..  Train MER: 0.134..  Validation MER: 0.109..
# Epoch: 151/160..  Train Loss: 1.724..  Train MER: 0.138..  Validation MER: 0.116..

# %%
import torch.nn as nn
# !pip install octane
import octane
import torch.optim as optim

# Define your model structure (as you provided)
def create_model(dropout_rate):
    model = nn.Sequential(
        nn.Linear(train_features.shape[1], 512),
        nn.ReLU(),
        nn.Dropout(dropout_rate),
        nn.Linear(512, 256),
        nn.ReLU(),
        nn.Dropout(dropout_rate),
        nn.Linear(256, 128),
        nn.ReLU(),
        nn.Dropout(dropout_rate),
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Dropout(dropout_rate),
        nn.Linear(64, 32),
        nn.ReLU(),
        nn.Dropout(dropout_rate),
        nn.Linear(32, 16),
        nn.ReLU(),
        nn.Dropout(dropout_rate),
        nn.Linear(16, 8),
        nn.ReLU(),
        nn.Dropout(dropout_rate),
        nn.Linear(8, 1)
    )
    return model.to(device)

def train(model, train_loader, optimizer, criterion, device):
    model.train()  # Set the model to training mode
    total_loss = 0.0
    train_error_rates = torch.tensor([]).to(device)

    for features, labels in train_loader:
        features, labels = features.to(device), labels.to(device)
        optimizer.zero_grad()
        output = model(features)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        train_error_rate = torch.absolute(output / labels - 1)
        train_error_rates = torch.cat((train_error_rates, train_error_rate), dim=0)

    average_loss = total_loss / len(train_loader)
    median_train_error = torch.median(train_error_rates).item()
    return average_loss, median_train_error

def validate(model, valid_loader, criterion, device):
    model.eval()  # Set the model to evaluation mode
    validation_error_rates = torch.tensor([]).to(device)
    with torch.no_grad():
        for features, labels in valid_loader:
            features, labels = features.to(device), labels.to(device)
            output = model(features)
            validation_error_rate = torch.absolute(output / labels - 1)
            validation_error_rates = torch.cat((validation_error_rates, validation_error_rate), dim=0)

    median_validation_error = torch.median(validation_error_rates).item()
    return median_validation_error


def objective(trial):
    criterion = nn.MSELoss()
    # Generate the hyperparameters
    dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.5)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-4, 1e-1)
    num_epochs = trial.suggest_int('num_epochs', 50, 200)

    model = create_model(dropout_rate)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Assuming you have a function to train and validate your model
    # Replace with your actual training loop and validation error calculation
    for epoch in range(num_epochs):
        train(model,train_loader,optimizer,criterion,device)  # Define your training loop
        val_error = validate(model, valid_loader,criterion,device)  # Define your validation function

    return val_error

# Create a study object and optimize the objective function
# !pip install optuna
import optuna
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)

# Best hyperparameters
print("Best hyperparameters:", study.best_params)
# Out:
# [I 2023-11-13 04:48:25,200] A new study created in memory with name: no-name-f0980cb5-fb82-4381-aa4c-51bf581be21f
# <ipython-input-96-39cb1e21d5b2>:71: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   dropout_rate = trial.suggest_uniform('dropout_rate', 0.0, 0.5)
# <ipython-input-96-39cb1e21d5b2>:72: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-4, 1e-1)
# [I 2023-11-13 04:48:44,296] Trial 0 finished with value: 0.12084305286407471 and parameters: {'dropout_rate': 0.13032049751972846, 'learning_rate': 0.015114994986245188, 'num_epochs': 54}. Best is trial 0 with value: 0.12084305286407471.
# [I 2023-11-13 04:49:46,027] Trial 1 finished with value: 0.12834608554840088 and parameters: {'dropout_rate': 0.08645714949457373, 'learning_rate': 0.0021174260130988184, 'num_epochs': 170}. Best is trial 0 with value: 0.12084305286407471.
# [I 2023-11-13 04:50:36,214] Trial 2 finished with value: 0.13396859169006348 and parameters: {'dropout_rate': 0.3608235115947266, 'learning_rate': 0.0031410471420082672, 'num_epochs': 137}. Best is trial 0 with value: 0.12084305286407471.
# [I 2023-11-13 04:51:31,192] Trial 3 finished with value: 0.09573537111282349 and parameters: {'dropout_rate': 0.16208153027801098, 'learning_rate': 0.00016479632329145953, 'num_epochs': 154}. Best is trial 3 with value: 0.09573537111282349.
# [I 2023-11-13 04:52:33,775] Trial 4 finished with value: 0.098518967628479 and parameters: {'dropout_rate': 0.18990543782331049, 'learning_rate': 0.00010530029825717612, 'num_epochs': 178}. Best is trial 3 with value: 0.09573537111282349.
# [I 2023-11-13 04:53:16,476] Trial 5 finished with value: 0.19737505912780762 and parameters: {'dropout_rate': 0.31406626246569086, 'learning_rate': 0.00010273039888380225, 'num_epochs': 121}. Best is trial 3 with value: 0.09573537111282349.
# [I 2023-11-13 04:54:13,771] Trial 6 finished with value: 0.36266088485717773 and parameters: {'dropout_rate': 0.38777165697140936, 'learning_rate': 0.02999181937568508, 'num_epochs': 161}. Best is trial 3 with value: 0.09573537111282349.
# [I 2023-11-13 04:55:25,270] Trial 7 finished with value: 0.10835051536560059 and parameters: {'dropout_rate': 0.21713158882309247, 'learning_rate': 0.00037742217714920273, 'num_epochs': 196}. Best is trial 3 with value: 0.09573537111282349.
# [I 2023-11-13 04:55:45,033] Trial 8 finished with value: 0.12845265865325928 and parameters: {'dropout_rate': 0.04903715764004829, 'learning_rate': 0.016656211893056456, 'num_epochs': 53}. Best is trial 3 with value: 0.09573537111282349.
# [I 2023-11-13 04:56:46,028] Trial 9 finished with value: 0.1390809416770935 and parameters: {'dropout_rate': 0.4096828201177243, 'learning_rate': 0.0019904849490750536, 'num_epochs': 173}. Best is trial 3 with value: 0.09573537111282349.
# Best hyperparameters: {'dropout_rate': 0.16208153027801098, 'learning_rate': 0.00016479632329145953, 'num_epochs': 154}

# %%
best_model = create_model(0.16208153027801098)
train_losses, train_errors, validation_errors = train_norm(best_model,train_loader, num_epochs=154, learning_rate=0.00016479632329145953)
# Out:
# Epoch: 1/154..  Train Loss: 30.850..  Train MER: 0.951..  Validation MER: 0.941..
# Epoch: 11/154..  Train Loss: 5.111..  Train MER: 0.249..  Validation MER: 0.209..
# Epoch: 21/154..  Train Loss: 4.381..  Train MER: 0.228..  Validation MER: 0.189..
# Epoch: 31/154..  Train Loss: 3.791..  Train MER: 0.209..  Validation MER: 0.169..
# Epoch: 41/154..  Train Loss: 3.667..  Train MER: 0.205..  Validation MER: 0.131..
# Epoch: 51/154..  Train Loss: 3.682..  Train MER: 0.195..  Validation MER: 0.166..
# Epoch: 61/154..  Train Loss: 3.261..  Train MER: 0.193..  Validation MER: 0.139..
# Epoch: 71/154..  Train Loss: 3.168..  Train MER: 0.182..  Validation MER: 0.114..
# Epoch: 81/154..  Train Loss: 3.039..  Train MER: 0.176..  Validation MER: 0.112..
# Epoch: 91/154..  Train Loss: 2.956..  Train MER: 0.173..  Validation MER: 0.113..
# Epoch: 101/154..  Train Loss: 2.674..  Train MER: 0.163..  Validation MER: 0.113..
# Epoch: 111/154..  Train Loss: 2.722..  Train MER: 0.160..  Validation MER: 0.104..
# Epoch: 121/154..  Train Loss: 2.511..  Train MER: 0.156..  Validation MER: 0.103..
# Epoch: 131/154..  Train Loss: 2.339..  Train MER: 0.150..  Validation MER: 0.104..
# Epoch: 141/154..  Train Loss: 2.321..  Train MER: 0.146..  Validation MER: 0.099..
# Epoch: 151/154..  Train Loss: 2.133..  Train MER: 0.140..  Validation MER: 0.093..

# %% [markdown]
# ---
# ## Save Model
#
# Save a `checkpoint.pth` file containing all the necessary information to retrieve your best model and predictions. Remember submitting this file to Canvas siste.
#
# Hint: Check out the `Lecture 4 - Saving and Loading Models.ipynb` on Canvas if you do not know how to save model.

# %%
torch.save(best_model.state_dict(), 'checkpoint.pth')

# %% [markdown]
# ---
# ## Inference on test data
#
# After the model is trained, we can use it for inference.

# %%
#TODO: write the code to generate predicted sale prices for test data
dataiter = iter(test_loader)
features,= next(dataiter)
features=features.to(device)
output = model(features)

def test(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    # In evaluation (or testing) mode, we don't want any parameter updates. We want the model to give
    # the final output based on current parameter values.
    pred_labels = torch.tensor([]).to(device)
    with torch.no_grad():
      for features, in test_loader:
            # Move data to device (GPU or CPU)
            features = features.to(device)
            output = model(features)  # Compute the output
            # store prediction results
            pred_labels = torch.cat( (pred_labels,output),dim=0)
    return  pred_labels

pred_labels =test(best_model,test_loader)

# %%
#TODO: save the predicted sale prices into submission_csv
pred_labels=pred_labels*normalization_factor

# %%
pred_labels[:20]
# Out:
# tensor([[ 530322.0625],
#         [ 486053.1875],
#         [ 453851.8438],
#         [ 267549.5312],
#         [ 577843.8125],
#         [ 374403.1562],
#         [ 388033.6875],
#         [ 507757.4375],
#         [ 429668.0312],
#         [ 305792.1562],
#         [ 336712.0312],
#         [ 511913.2188],
#         [ 474107.8750],
#         [ 304521.1875],
#         [1122260.8750],
#         [ 249590.5938],
#         [ 392716.3750],
#         [ 191928.1875],
#         [ 216498.1094],
#         [1124839.2500]], device='cuda:0')

# %%
data = {'ID': test_ID, 'SALE_PRICE': pred_labels.cpu().numpy().squeeze()}
pred_df=pd.DataFrame(data)
pred_df.head()
# Out:
#        ID    SALE_PRICE
# 0  144650  530322.06250
# 1  495961  486053.18750
# 2  582423  453851.84375
# 3  966643  267549.53125
# 4  795229  577843.81250

# %%
pred_df.to_csv('submission.csv', index=False)

# %% [markdown]
# Now, we can submit our predictions on Kaggle and see how they compare with the actual house prices (labels) on the test set.
#
# - Log in to the Kaggle website and visit the house price prediction competition page.
#
# - Click the “Submit Predictions”.
#
# - Click the “Browse Files” button in the dashed box at the bottom of the page and select the prediction file you wish to upload.
#
# - Click the “Submit” button at the bottom of the page to view your results.

# %% [markdown]
#  **Include your best test error shown on Kaggle in your case report!**

# %% [markdown]
# ---
# ## Evaluate the profit of iBuyer business model
#
#
# In class, we have dicussed the iBuyer business model and its opportunities and risks. In the following analysis, imagine you work in a consulting firm and would like to investigate the profitability of the iBuyer business model.
#
# You have taken the Mordern Analytics course and remembered that Prof. X advocated the data-driven approach in business decision making. Thus, you would like to perform analysis based on model and data.
#
# Note that since we do not know the true sale prices in the future (like test data), we need to conduct the analysis based on the historical data (train or validation data). Previously, you have already trained a multilayer perceptron model using the train data. Now, let's evaluate the profit of iBuyer business model based on the predicted prices on the **validation data**.

# %% [markdown]
# Let's first compute the predicted prices on the valid data.

# %%
## TODO: Load your best model from your saved checkpoint.pth file.
model = create_model(0.04318294098072889)
model.load_state_dict(torch.load("checkpoint.pth"))
#newestmodel.eval()
model = model.to(device)

# %%
## TODO: compute the predicted prices on valid data using your best model
def test(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    # In evaluation (or testing) mode, we don't want any parameter updates. We want the model to give
    # the final output based on current parameter values.
    pred_labels = torch.tensor([]).to(device)
    with torch.no_grad():
      for features,_ in test_loader:
            # Move data to device (GPU or CPU)
            features = features.to(device)
            #label = label.to(device)
            output = model(features)  # Compute the output
            # store prediction results
            pred_labels = torch.cat( (pred_labels,output),dim=0)
    return  pred_labels
pred_labels = test(model, valid_loader)
pred_labels=pred_labels*normalization_factor
pred_labels[:20]
# Out:
# tensor([[ 619710.2500],
#         [ 574619.5625],
#         [ 327572.5312],
#         [ 377406.9688],
#         [1208866.8750],
#         [ 667216.0000],
#         [ 368993.3438],
#         [ 439888.2500],
#         [ 263558.5938],
#         [ 221021.1719],
#         [ 644536.1875],
#         [ 550102.6250],
#         [ 350465.5000],
#         [ 846610.3750],
#         [ 376720.3438],
#         [ 424098.5312],
#         [ 665314.5000],
#         [ 265126.4688],
#         [ 346494.0938],
#         [ 595371.6250]], device='cuda:0')

# %%
data = {'ID': valid_indices, 'SALE_PRICE': pred_labels.cpu().numpy().squeeze()}
pred_df=pd.DataFrame(data)
pred_df.head()
# Out:
#       ID    SALE_PRICE
# 0   5820  6.197102e+05
# 1   1971  5.746196e+05
# 2   8366  3.275725e+05
# 3  11291  3.774070e+05
# 4   3090  1.208867e+06

# %% [markdown]
# Compute the signed error rates (without taking the absolute value sign), that is
#
# $$
# \text{Signed Error Rate} = \frac{\text{Predicted Price}-\text{Actual Price}}{\text{Actual Price}}
# $$
# We will call signed error rate as prediction error henceafter.

# %%
## TODO: compute the signed error rates (henceafter called prediction errors)
valid_price = valid_labels.cpu().detach().numpy().squeeze()*normalization_factor
signed_error_rate = (pred_df.SALE_PRICE - valid_price)/valid_price

# %% [markdown]
# ### Analysis and visualization of valid errors

# %% [markdown]
# Let's plot the histogram of prediction errors.
#
# **Question 1**: what is the bias of the prediction errors? Include the histogram of prediction errors and the bias in your report.

# %%
plt.hist(signed_error_rate, bins=80, range= (-1.5,1.5))
plt.show()

bias = np.mean(signed_error_rate)
bias
# Out:
# 0.01976280650231896

# %% [markdown]
# ### Profit Analysis
#
# In the following profit analysis, we assume the iBuyer will make an offer to every property in the valid data based on their predicted price $PP$. We assume the iBuyer decides the offer price $OP$ according to
# $$
# OP = \frac{PP}{1+\alpha},
# $$
# where $\alpha$ is the (targted) profit margin of the iBuyer.
# Here we assume the profit margin has already taken into consideration the commission fee charged by the iBuyer
# and various costs associated such as transaction cost, administration cost, and holding cost. Note that the commission fee charged by Zillow is often around $7.5\%$ and Zillow may charge additional repair costs after home inspection. Thus we take $\alpha=12\%$ in this case study.
#
# We further assume that the iBuyer can resell the property at the same
# price as the broker in the future once the property is bought. In other words, the resell price is equal to the sale price in the valid data. This assumption may not be exactly true in practice and the iBuyer may sell the house at either a higher or lower price depending on the market trend. But our conclusion will not change too much.
#
# Based on the above two assumptions, we can now determine the percentage profit
# for a property bought by the iBuyer as
# $$
# \frac{SP- OP}{OP}.
# $$
# We use the percentage profit instead of the absolute profit because the iBuyer cannot hope to purchase all houses in the market. Therefore, the percentage profit is a better measure of the profitability of the iBuyer business model.
#  The aim of the iBuyer in this simplified setting is to purchase properties for less money than they are sold for, to generate a profit.

# %%
profit_margin = 0.12

# %% [markdown]
# **Question 2**: Consider the hypothetical scenario where the offers are all accepted regardless of their values,
# what is the average percentage profit? Do you see a big difference compared to the profit margin $\alpha$? Include your answers in the report.

# %%
offer_price = pred_df.SALE_PRICE/(1+profit_margin)
percentage_profit = (valid_price - offer_price)/offer_price
percentage_profit.mean()
# Out:
# 0.15405174741056923

# %% [markdown]
# **Offer Acceptance Rule**
#
#
# However, not every offer will be accepted by the home owner. Given an offer price, whether the homeowner accepts it
# depends on the homeowner's perceived valuation. For the current dataset, we lack enough data to determine the homeowner's perceived valuation of the property. However, the actual sale price in the valid data serves as a reasonable proxy of the homeowner's perceived valuation. Therefore, we assume that the home owner will accept the offer, if
# $$
# OP> (1-\beta) SP,
# $$
# where $\beta$ is a discounting factor. Here the discounting factor captures the commission fee charged
# by the conventional realtors which is around 6%, as well as the convenience factor that models
# how much the homeowner values the quick transaction services of the iBuyer over the conventional
# relator. We assume $\beta = 10\%$ in this case.

# %% [markdown]
# **Question 3**: Based on the sale price in the valid data and the acceptance rule, what is the mean percentage profit among all accepted offers? Do you see a big difference compared to the targeted profit margin $\alpha$?  Include your answers in your report.

# %%
take_offer = []
for o_price, v_price in zip(offer_price, valid_price):
    if o_price > 0.9 * v_price:
        take_offer.append((v_price - o_price) / o_price)

print(np.mean(take_offer))
# Out:
# -0.029896584086388015

# %% [markdown]
# Let's plot the histogram of the prediction errors for those properties whose home owners accepted the offer.
#
# **Question 4**: What is the bias of the prediction errors when restricting to those properties whose owners accepted the offer? Based on the histogram and bias, can you explain your answers to Question 3?

# %%
plt.hist(take_offer, bins=80, range= (-1.5,1.5))
plt.show()
